# %% [markdown]
# <a href="https://colab.research.google.com/github/WillFerreiraSantos/LLM_PortugueseLegalDocClassifier/blob/main/mistralai_Mixtral_8x22B_Instruct_v0_1_Descri%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install tiktoken langchain-community langchainhub langchain_openai langchain
# !!pip install imbalanced-learn

from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

api_key = ''

llm = ChatOpenAI(
                api_key= api_key,
                base_url="https://api.together.xyz/v1",
                model='mistralai/Mixtral-8x22B-Instruct-v0.1',
                max_tokens=100,
                temperature=0.1,
                verbose=True
                )

def get_label(result):
    return result.content
# Out:
# Mounted at /content/drive
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.9 MB/s eta 0:00:00
# Collecting langchain-community
#   Downloading langchain_community-0.2.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.7 MB/s eta 0:00:00
# Collecting langchainhub
#   Downloading langchainhub-0.1.20-py3-none-any.whl (5.0 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-0.1.17-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 6.2 MB/s eta 0:00:00
# Collecting langchain
#   Downloading langchain-0.2.9-py3-none-any.whl (987 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.7/987.7 kB 59.9 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting langchain-core<0.3.0,>=0.2.12 (from langchain-community)
#   Downloading langchain_core-0.2.21-py3-none-any.whl (372 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.0/372.0 kB 36.7 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-community)
#   Downloading langsmith-0.1.92-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.0/135.0 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.25.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (24.1)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.32.0.20240712-py3-none-any.whl (15 kB)
# Collecting openai<2.0.0,>=1.32.0 (from langchain_openai)
#   Downloading openai-1.35.15-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.6/328.6 kB 37.6 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.3 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.12->langchain-community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain-community)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain_openai) (1.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.0 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain-community)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: types-requests, orjson, mypy-extensions, marshmallow, jsonpointer, h11, typing-inspect, tiktoken, langchainhub, jsonpatch, httpcore, langsmith, httpx, dataclasses-json, openai, langchain-core, langchain-text-splitters, langchain_openai, langchain, langchain-community
# Successfully installed dataclasses-json-0.6.7 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.9 langchain-community-0.2.7 langchain-core-0.2.21 langchain-text-splitters-0.2.2 langchain_openai-0.1.17 langchainhub-0.1.20 langsmith-0.1.92 marshmallow-3.21.3 mypy-extensions-1.0.0 openai-1.35.15 orjson-3.10.6 tiktoken-0.7.0 types-requests-2.32.0.20240712 typing-inspect-0.9.0

# %%
PROMPT_CLASSIFICACAO = (
    "Classifique as petições processuais abaixo em uma das seguintes categorias: "
    "AGRAVO, CONTRARRAZOES-AO-AGRAVO, EMBARGOS, EXTINCAO-DE-PUNIBILIDADE, "
    "HABEAS-CORPUS, IMPUGNACAO, INDULTO-COMUTACAO, INTIMACAO-NEGATIVA, "
    "LIVRAMENTO-CONDICIONAL, OFICIOS, PROGRESSAO-DE-REGIME, REMICAO-DE-PENA, "
    "TRANSFERENCIA-DE-EXECUCAO, UNIFICACAO-DE-PENAS, APELACAO, REGISTRO-CIVIL, "
    "CUMPRIMENTO-DE-SETENCA, INDENIZATORIAS, EXCECAO-DE-PRE-EXECUTIVIDADE, "
    "DISSOLUCAO-DE-CONDOMINIO, CONSIGNACAO-EM-PAGAMENTO, ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, "
    "SAIDA-TEMPORARIA, USUCAPIAO. "
    "Retorne apenas a categoria e nada mais. "
    "Texto: {texto} "
    "Categoria:"
)

PROMPT_RESUMO = (
    "Faça um resumo explicativo de 200 palavras da petição abaixo, o resumo deve descrever sobre o que o texto fala de modo geral, "
    "ignorando pessoas, números, locais, ou especificidades que não definem a ideia da petição, permitindo a classificação da petição "
    "entre as seguintes classes: AGRAVO, CONTRARRAZOES-AO-AGRAVO, EMBARGOS, EXTINCAO-DE-PUNIBILIDADE, "
    "HABEAS-CORPUS, IMPUGNACAO, INDULTO-COMUTACAO, INTIMACAO-NEGATIVA, "
    "LIVRAMENTO-CONDICIONAL, OFICIOS, PROGRESSAO-DE-REGIME, REMICAO-DE-PENA, "
    "TRANSFERENCIA-DE-EXECUCAO, UNIFICACAO-DE-PENAS, APELACAO, REGISTRO-CIVIL, "
    "CUMPRIMENTO-DE-SETENCA, INDENIZATORIAS, EXCECAO-DE-PRE-EXECUTIVIDADE, "
    "DISSOLUCAO-DE-CONDOMINIO, CONSIGNACAO-EM-PAGAMENTO, ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, "
    "SAIDA-TEMPORARIA, USUCAPIAO. "
    "Retorne apenas o resumo explicativo e nada mais. "
    "---------------------- "
    "Petição de {classe}: {texto}"
    "Resumo Explicativo:"
)

PROMPT_DESCRICAO = (
    "Classifique a petição processual nas seguintes categorias: "
    "- AGRAVO: Petições que contestam decisões judiciais, solicitando a revisão dessas decisões, geralmente por inconformidade com a decisão proferida em primeira instância. "
    "- CONTRARRAZOES-AO-AGRAVO: Petições que apresentam argumentos contrários a um agravo interposto, defendendo a manutenção da decisão judicial atacada e refutando os pontos levantados pelo agravante. "
    "- EMBARGOS: Petições que visam esclarecer ou corrigir omissões, contradições ou obscuridades em decisões judiciais, buscando a perfeita compreensão e aplicação da decisão. "
    "- EXTINCAO-DE-PUNIBILIDADE: Petições que tratam da extinção da punibilidade de uma pena por razões como prescrição, anistia, perdão judicial ou cumprimento integral da pena imposta. "
    "- HABEAS-CORPUS: Petições que visam garantir a liberdade de um indivíduo, alegando prisão ilegal ou abuso de poder, e buscando a concessão do benefício de soltura imediata. "
    "- IMPUGNACAO: Petições que questionam a precisão de relatórios ou decisões processuais, solicitando correções específicas para assegurar a justiça e a veracidade dos documentos processuais. "
    "- INDULTO-COMUTACAO: Petições que solicitam a comutação ou redução de pena com base em decretos presidenciais, leis específicas ou outros fundamentos legais que justifiquem o benefício. "
    "- INTIMACAO-NEGATIVA: Petições que tratam da intimação do sentenciado que não foi localizado, solicitando nova tentativa de intimação ou a adoção de outras medidas para assegurar a comunicação processual. "
    "- LIVRAMENTO-CONDICIONAL: Petições que solicitam a concessão de livramento condicional, alegando que o apenado cumpriu os requisitos legais, como bom comportamento e cumprimento de parte da pena. "
    "- OFICIOS: Solicitações formais de providências ou informações sobre o andamento de processos penais, destacando a importância da celeridade e da razoável duração do processo para a garantia dos direitos dos envolvidos. "
    "- PROGRESSAO-DE-REGIME: Petições que solicitam a progressão de regime prisional para um apenado, alegando que este cumpriu os requisitos legais, como o cumprimento de parte da pena e bom comportamento. "
    "- REMICAO-DE-PENA: Petições que solicitam a remição de pena por estudo ou trabalho realizado durante o cumprimento da pena, destacando o esforço do apenado em se reintegrar à sociedade. "
    "- TRANSFERENCIA-DE-EXECUCAO: Petições que solicitam a transferência da execução da pena para uma comarca mais próxima da residência do apenado, visando facilitar o acompanhamento familiar e a reintegração social. "
    "- UNIFICAO-DE-PENAS: Petições que tratam da unificação de penas decorrentes de diferentes processos, visando a fixação de um regime de cumprimento único e adequado à situação do apenado. "
    "- APELACAO: Petições que solicitam a reavaliação de uma decisão judicial em instância superior. "
    "- REGISTRO-CIVIL: Petições relacionadas ao registro de nascimentos, casamentos, óbitos e outros atos civis. "
    "- CUMPRIMENTO-DE-SETENCA: Petições que solicitam a execução de uma decisão judicial já transitada em julgado. "
    "- INDENIZATORIAS: Petições que solicitam compensação financeira por danos sofridos. "
    "- EXCECAO-DE-PRE-EXECUTIVIDADE: Petições que buscam a extinção de um processo executivo antes da sua efetiva execução, geralmente por questões de ordem pública. "
    "- DISSOLUCAO-DE-CONDOMINIO: Petições que solicitam a dissolução de um condomínio e a partilha de seus bens. "
    "- CONSIGNACAO-EM-PAGAMENTO: Petições que buscam depositar judicialmente um valor devido, quando o credor se recusa a receber o pagamento diretamente. "
    "- ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: Petições que solicitam a liberação de um corpo para sepultamento. "
    "- SAIDA-TEMPORARIA: Petições que solicitam a autorização para que o apenado saia temporariamente da prisão por razões específicas, como visita à família. "
    "- USUCAPIAO: Petições que buscam o reconhecimento da aquisição da propriedade de um bem por meio de sua posse prolongada e contínua. "
    "--------------------- "
    "Retorne apenas a classe e nada mais. "
    "Petição: {texto} "
    "Classe:"
)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calcular média e mediana
mean_value = df['token_count'].mean()
median_value = df['token_count'].median()

# Plotar histograma da quantidade de tokens
plt.figure(figsize=(6, 4))
plt.hist(df['token_count'], bins=30, edgecolor='black')
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Média: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {median_value:.2f}')
plt.xlabel('Número de Tokens', fontsize=12)
plt.ylabel('Frequência', fontsize=12)
plt.title('Histograma da Quantidade de Tokens', fontsize=15)
plt.legend()
plt.show()

# %%
import pandas as pd

# Carregar o dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/test_data.csv')

# Selecionar um exemplo de cada categoria de 1 a 24
unique_labels = range(1, 25)
examples = []

for label in unique_labels:
    example = df[df['issue_area_label'] == label].head(1)
    examples.append(example)

# Concatenar todos os exemplos em um único DataFrame
examples_df = pd.concat(examples)

# Selecionar as colunas de interesse
selected_columns = examples_df[['issue_area', 'issue_area_label']]

# Exibir o dataset com as colunas selecionadas
from IPython.display import display

display(selected_columns)

print(selected_columns)
# Out:
#                              issue_area  issue_area_label
# 1                                AGRAVO                 1
# 104  ALVARA-JUDICIAL-LIBERACAO-DE-CORPO                 2
# 10                             APELACAO                 3
# 125            CONSIGNACAO-EM-PAGAMENTO                 4
# 224             CONTRARRAZOES-AO-AGRAVO                 5
# 18               CUMPRIMENTO-DE-SETENCA                 6
# 11             DISSOLUCAO-DE-CONDOMINIO                 7
# 6                              EMBARGOS                 8
# 59         EXCECAO-DE-PRE-EXECUTIVIDADE                 9
# 7              EXTINCAO-DE-PUNIBILIDADE                10
# 19                        HABEAS-CORPUS                11
# 5                            IMPUGNACAO                12
# 4                        INDENIZATORIAS                13
# 34                    INDULTO-COMUTACAO                14
# 0                    INTIMACAO-NEGATIVA                15
# 9                LIVRAMENTO-CONDICIONAL                16
# 8                               OFICIOS                17
# 43                 PROGRESSAO-DE-REGIME                18
# 2                        REGISTRO-CIVIL                19
# 22                      REMICAO-DE-PENA                20
# 88                     SAIDA-TEMPORARIA                21
# 62            TRANSFERENCIA-DE-EXECUCAO                22
# 26                  UNIFICACAO-DE-PENAS                23
# 65                            USUCAPIAO                24
#                              issue_area  issue_area_label
# 1                                AGRAVO                 1
# 104  ALVARA-JUDICIAL-LIBERACAO-DE-CORPO                 2
# 10                             APELACAO                 3
# 125            CONSIGNACAO-EM-PAGAMENTO                 4
# 224             CONTRARRAZOES-AO-AGRAVO                 5
# 18               CUMPRIMENTO-DE-SETENCA                 6
# 11             DISSOLUCAO-DE-CONDOMINIO                 7
# 6                              EMBARGOS                 8
# 59         EXCECAO-DE-PRE-EXECUTIVIDADE                 9
# 7              EXTINCAO-DE-PUNIBILIDADE                10
# 19                        HABEAS-CORPUS                11
# 5                            IMPUGNACAO                12
# 4                        INDENIZATORIAS                13
# 34                    INDULTO-COMUTACAO                14
# 0                    INTIMACAO-NEGATIVA                15
# 9                LIVRAMENTO-CONDICIONAL                16
# 8                               OFICIOS                17
# 43                 PROGRESSAO-DE-REGIME                18
# 2                        REGISTRO-CIVIL                19
# 22                      REMICAO-DE-PENA                20
# 88                     SAIDA-TEMPORARIA                21
# 62            TRANSFERENCIA-DE-EXECUCAO                22
# 26                  UNIFICACAO-DE-PENAS                23
# 65                            USUCAPIAO                24

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_distances
import numpy as np
import pandas as pd

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(filtered_df['facts'])

labels = filtered_df['issue_area'].unique()
centroids = []

for label in labels:
    indices = filtered_df['issue_area'] == label
    cluster_vectors = X[indices]
    cluster_texts = filtered_df['facts'][indices]

    centroid_vector = cluster_vectors.mean(axis=0)
    centroid_vector = np.asarray(centroid_vector).flatten()

    distances = cosine_distances(cluster_vectors, centroid_vector.reshape(1, -1))
    closest_index = np.argmin(distances)
    centroid_text = cluster_texts.iloc[closest_index]

    centroids.append({'issue_area': label, 'centroid_text': centroid_text})

# Criar DataFrame com os centróides
centroids_df = pd.DataFrame(centroids)

# Exibir as centróides no terminal
print("Centróides:")
print(centroids_df)

# Salvar os resultados em arquivos CSV e Excel
csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Texto-centroids/centroids.csv'
excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Texto-centroids/centroids.xlsx'

centroids_df.to_csv(csv_path, index=False)
centroids_df.to_excel(excel_path, index=False)

print(f"Results saved to {csv_path} and {excel_path}")
# Out:
# Centróides:
#                             issue_area  \
# 0                   INTIMACAO-NEGATIVA
# 1                               AGRAVO
# 2                       REGISTRO-CIVIL
# 3                       INDENIZATORIAS
# 4                           IMPUGNACAO
# 5                             EMBARGOS
# 6             EXTINCAO-DE-PUNIBILIDADE
# 7                              OFICIOS
# 8               LIVRAMENTO-CONDICIONAL
# 9                             APELACAO
# 10            DISSOLUCAO-DE-CONDOMINIO
# 11              CUMPRIMENTO-DE-SETENCA
# 12                       HABEAS-CORPUS
# 13                     REMICAO-DE-PENA
# 14                 UNIFICACAO-DE-PENAS
# 15                   INDULTO-COMUTACAO
# 16                PROGRESSAO-DE-REGIME
# 17        EXCECAO-DE-PRE-EXECUTIVIDADE
# 18           TRANSFERENCIA-DE-EXECUCAO
# 19                           USUCAPIAO
# 20                    SAIDA-TEMPORARIA
# 21  ALVARA-JUDICIAL-LIBERACAO-DE-CORPO
# 22            CONSIGNACAO-EM-PAGAMENTO
# 23             CONTRARRAZOES-AO-AGRAVO
#
#                                         centroid_text
# 0   ao juízo da vara de execução de pena e medidas...
# 1   ao juízo da vara de execução de penas e medida...
# 2   juizo direito vara fazenda publica municipal r...
# 3   juizo civel comarca goiania go jose lope silva...
# 4   excelentissimo senhor doutor juiz direito vara...
# 5   excelentissimo senhor doutor juiz direito vara...
# 6   ao juízo da 3ª vara de execução penal da comar...
# 7   ofício nep n 682020 goiânia 03 de junho de 202...
# 8   ao juízo da 3ª vara de execução penal da comar...
# 9   excelentissimo senhor doutor juiz direito vara...
# 10  juizo vara civel comarca goiania go silvio jos...
# 11  excelentissimo senhor doutor juiz direito vara...
# 12  excelentíssimo senhor doutor desembargador pre...
# 13  ao juízo da 3ª vara de execução penal da comar...
# 14  ao juízo da 3ª vara de execução penal da comar...
# 15  ao juízo da vara de execução de penas e medida...
# 16  ao juízo da 3ª vara de execução penal da comar...
# 17  excelentissimo senhor doutor juiz direito vara...
# 18  ao juízo da 3ª vara de execução de penal da co...
# 19  juizo direito vara civel comarca goiania goias...
# 20  ao juízo da 3ª vara de execução penal da comar...
# 21  juizo plantonista comarca goiania go joao marc...
# 22  juizo vara civel comarca goiania goias viniciu...
# 23  ao juízo da vara de execução de penas e medida...
# Results saved to /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Texto-centroids/centroids.csv and /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Texto-centroids/centroids.xlsx

# %%
prompt_template_resumo = PromptTemplate(
    input_variables=["texto","classe"],
    template=PROMPT_RESUMO,
)

chain_resumo = prompt_template_resumo | llm | get_label

resumos = []

for label, centroid in zip(labels, centroids):
    resumo = chain_resumo.invoke({'texto': centroid['centroid_text'], 'classe': label})
    resumos.append(resumo)
    print(f"\nResumo para {label}:\n{resumo}\n")
# Out:
# Resumo para INTIMACAO-NEGATIVA:
#  A petição trata de uma Intimação Negativa, onde a Defensoria Pública do Estado de Goiás solicita ao Juízo da Vara de Execução de Pena e Medidas Alternativas da Comarca de Goiânia que o sentenciado, cujo nome foi anonimizado, compareça a uma audiência admonitória. A Defensoria Pública, representada pela defensora pública
#
#
# Resumo para AGRAVO:
#  A petição trata de um agravo interposto pela defensoria pública em nome de um indivíduo que cumpriu integralmente sua pena corporal, convertida em restritiva de direitos, mas não pôde pagar a multa imposta. A defensoria argumenta que, apesar da pendência do pagamento da multa, a punibilidade do indivíduo deve ser declarada
#
#
# Resumo para REGISTRO-CIVIL:
#  A petição trata de uma solicitação de REGISTRO-CIVIL para a retificação de um registro civil. A requerente, que está em situação de hipossuficiência econômica, solicita a concessão de gratuidade da justiça para arcar com os custos processuais e honorários advocatícios. A defensoria pública do estado de Goiás represent
#
#
# Resumo para INDENIZATORIAS:
#  A petição trata de uma ação de indenização por danos materiais e morais, onde o requerente, José Lope Silva, busca o ressarcimento de prejuízos sofridos em decorrência de um acidente de trabalho e de conduta ilícita de dois advogados que o representaram em processos judiciais. O requerente contratou o primeiro adv
#
#
# Resumo para IMPUGNACAO:
#  A petição trata de uma ação de impugnação, onde o requerente, assistido pela Defensoria Pública do Estado de Goiás, questiona o cumprimento de uma sentença relacionada ao pagamento de taxas de condomínio. O requerente argumenta que houve uma violação do devido processo legal, uma vez que não houve a devida intimidade pessoal durante a f
#
#
# Resumo para EMBARGOS:
#  A petição trata de um pedido de Embargos, onde o defensor público, atuando como curador especial, questiona a validade de uma ação monitora. O defensor argumenta que as prerrogativas dos membros da defensoria pública devem ser respeitadas, incluindo o prazo dobrado para intimar pessoalmente o réu. Ele também cita jurisprudência superior que
#
#
# Resumo para EXTINCAO-DE-PUNIBILIDADE:
#  A petição trata de uma solicitação de extinção de punibilidade para um indivíduo conhecido como Leonir Francisco Carlos, que foi condenado a uma pena unificada de 5 anos e 6 meses de reclusão por dois crimes, um deles envolvendo o uso de uma arma branca. A defesa argumenta que, após a revogação do inciso i do §
#
#
# Resumo para OFICIOS:
#  A petição trata de um ofício solicitando informações sobre a manutenção da prisão de um indivíduo, cujo nome foi anonimizado. O indivíduo foi originalmente preso preventivamente em fevereiro de 2019, mas foi libertado em setembro de 2019 por meio de um alvará de soltura. No entanto, devido a
#
#
# Resumo para LIVRAMENTO-CONDICIONAL:
#  A petição trata de uma solicitação de livramento condicional para um indivíduo que está cumprindo uma pena privativa de liberdade. O indivíduo está em tratamento médico neurológico e tem diagnóstico de disfunção executiva, transtorno cognitivo e de personalidade pós-traumático. A petição argumenta que o direito à saúde é
#
#
# Resumo para APELACAO:
#  A petição trata de uma apelação interposta pela Defensoria Pública do Estado de Goiás em nome da apelante Rita Vanessa Alves Bandiera contra a decisão do juiz de primeira instância que extinguiu o processo. A defesa argumenta que houve uma violação ao direito de defesa, uma vez que a Defensoria Pública não foi intimada pessoalmente, o que
#
#
# Resumo para DISSOLUCAO-DE-CONDOMINIO:
#  A petição trata de uma ação de DISSOLUÇÃO DE CONDOMÍNIO, onde o requerente solicita a extinção do condomínio existente sobre um imóvel adquirido em comum com a ex-cônjuge durante o casamento. O requerente argumenta que, após a separação e o divórcio, a ex-cônjuge tem exercido pl
#
#
# Resumo para CUMPRIMENTO-DE-SETENCA:
#  A petição trata de uma solicitação de Cumprimento de Sentença, onde o Banco do Brasil está buscando o pagamento de uma dívida de um indivíduo chamado Thiago Fernando Martin. A Defensoria Pública do Estado de Goiás está representando o executado. A petição destaca a necessidade de observância das prerrogativas dos membros da Defensoria P
#
#
# Resumo para HABEAS-CORPUS:
#  A petição trata de um pedido de habeas corpus para beneficiar o paciente Ubes Eropeu de Oliveira, que está atualmente recolhido na casa de prisão provisória do complexo prisional de Aparecida de Goiânia. O paciente foi condenado a uma pena de 02 anos e 06 meses de reclusão em regime inicial semiab
#
#
# Resumo para REMICAO-DE-PENA:
#  A petição trata de uma solicitação de remição de pena para um indivíduo que está cumprindo uma pena privativa de liberdade em regime aberto, em prisão domiciliar condicionada ao uso de monitoração eletrônica. O indivíduo é portador do vírus HIV e relata que a utilização da tornozeleira eletrônica tem representado um obstácul
#
#
# Resumo para UNIFICACAO-DE-PENAS:
#  A petição trata de uma solicitação de unificação de penas para um indivíduo que foi condenado a quatro anos de reclusão em regime inicial aberto por infração ao artigo 157 do Código Penal. O indivíduo foi incluído no regime aberto domiciliar com monitoração eletrônica, mas foi registrada uma suposta fuga. Post
#
#
# Resumo para INDULTO-COMUTACAO:
#  A petição trata de um pedido de indulto comutativo para um indivíduo que foi condenado a três anos de reclusão por uma infração e a quatro meses de prestação de serviços à comunidade por outra infração. O indulto é solicitado com base no decreto presidencial de 2017, que concede indulto coletivo a p
#
#
# Resumo para PROGRESSAO-DE-REGIME:
#  A petição trata de uma solicitação de progressão de regime para um indivíduo que está cumprindo uma pena em regime fechado. A defensoria pública do estado de Goiás está requerendo ao juízo da 3ª vara de execução penal da comarca de Goiânia que seja concedida a progressão para o regime semiaberto, uma vez que o indiví
#
#
# Resumo para EXCECAO-DE-PRE-EXECUTIVIDADE:
#  A petição trata de uma exceção de pre-executividade, um recurso excepcional que permite ao executado defender seus direitos e interesses antes da execução da sentença. O requerente argumenta que houve uma violação do direito à ampla defesa e ao contraditório, devido a uma citacão nula por edital, sem que tenham sido esgotadas as tent
#
#
# Resumo para TRANSFERENCIA-DE-EXECUCAO:
#  A petição solicita a transferência da execução da pena para uma comarca diferente, onde o condenado reside. O condenado está atualmente cumprindo a pena em regime aberto domiciliar com monitoração eletrônica. A defensoria pública argumenta que a reintegração social é o principal objetivo da execução penal e que é essencial que o condenado cumpra a p
#
#
# Resumo para USUCAPIAO:
#  A petição trata de uma ação de usucapião, que é um processo legal pelo qual uma pessoa pode adquirir a propriedade de um imóvel por meio da posse contínua e ininterrupta por um determinado período de tempo. Os requerentes, Adalberto e Ana Maria, afirmam ter adquirido o imóvel por meio da usucapião, tendo exercido
#
#
# Resumo para SAIDA-TEMPORARIA:
#  A petição trata de uma solicitação de saída temporária para um condenado que está cumprindo sua pena em regime aberto domiciliar com monitoração eletrônica. O condenado já recebeu autorização para saídas temporárias anteriores e agora está solicitando uma nova saída para visitar sua família na cidade de ipameri, Goiás. A petição argument
#
#
# Resumo para ALVARA-JUDICIAL-LIBERACAO-DE-CORPO:
#  A petição trata de uma solicitação de Alvará Judicial de Liberação de Corpo. O requerente, João Marcelo Souza Costa, solicita a expedição do alvará para a liberação do corpo de sua mãe falecida, Elizabeth Carla Souza Costa, para posterior traslado e sepultamento. O requerente enfatiza a necessidade de observância das prerrogativas
#
#
# Resumo para CONSIGNACAO-EM-PAGAMENTO:
#  A petição trata de uma ação de Consignação em Pagamento, onde o requerente solicita a concessão de gratuidade da justiça e a autorização para depositar a quantia devida em juízo. O requerente alega que não possui recursos suficientes para arcar com os custos processuais e honorários advocatícios, comprometendo sua própria
#
#
# Resumo para CONTRARRAZOES-AO-AGRAVO:
#  A petição trata de uma CONTRARRAZOES-AO-AGRAVO, onde a Defensoria Pública do Estado de Goiás apresenta argumentos contra o agravo interposto pelo Ministério Público em um processo penal. O agravado, Tássio Rodrigues Moreira, foi condenado a uma pena privativa de liberdade de 07 meses de detenção

# %%
# classifica os textos diretamente usando o PROMPT_DESCRICAO

import re
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import unicodedata

# Função para normalizar texto
def normalize_text(text):
    """
    Normaliza o texto para comparação.
    Converte para minúsculas e remove espaços extras.
    """
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Função para remover acentos
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return "".join([c for c in nfkd_form if not unicodedata.combining(c)])

# Função para limpar e normalizar a categoria
def clean_category(category):
    category = re.sub(r'[^a-zA-Z0-9\-]', '', category)
    category = re.sub(r'\s+', '-', category).strip()
    return category.upper()

# Função para encontrar a melhor correspondência
def get_best_match(result, valid_labels):
    result = clean_category(result)
    result = remove_accents(result).strip().upper()

    best_match = None
    best_score = -1

    for label in valid_labels:
        cleaned_label = clean_category(remove_accents(label.strip().upper()))
        if result == cleaned_label:
            return label
        score = len(set(result) & set(cleaned_label)) / len(set(result) | set(cleaned_label))
        if score > best_score:
            best_score = score
            best_match = label

    return best_match

# Inicializar variáveis para rastreamento das métricas
y_true = []
y_pred = []

# Variáveis para rastrear a acurácia
correct_count = 0
total_count = 0

# Lista para armazenar os resultados
results = []

# Lista de rótulos válidos
valid_labels = filtered_df['issue_area'].unique().tolist()

# Preparar o modelo para classificação com descrições
prompt_template_descricao = PromptTemplate(
    input_variables=["texto"],
    template=PROMPT_DESCRICAO,
)

chain_descricao = prompt_template_descricao | llm | get_label

# Classificação usando descrições diretamente nos textos das petições
for index, row in filtered_df.iterrows():
    texto_peticacao = row['facts']
    prompt_with_descricao = prompt_template_descricao.format(texto=texto_peticacao)
    result = chain_descricao.invoke({'texto': texto_peticacao}).strip()

    normalized_label = clean_category(remove_accents(row['issue_area'].strip().upper()))
    normalized_result = get_best_match(result, valid_labels)

    is_correct = normalized_label == clean_category(remove_accents(normalized_result.strip().upper()))

    print(f'Real: {row["issue_area"]}, Previsto: {normalized_result}, Correto: {is_correct}')

    y_true.append(normalized_label)
    y_pred.append(clean_category(remove_accents(normalized_result.strip().upper())))

    total_count += 1
    if is_correct:
        correct_count += 1

    intermediate_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    print(f'Progresso: {index + 1}/{len(filtered_df)}')
    print(f'Acurácia até agora: {correct_count / total_count * 100:.2f}%')
    print(f'Precisão até agora: {intermediate_precision * 100:.2f}%')
    print(f'Recall até agora: {intermediate_recall * 100:.2f}%')
    print(f'F1-score até agora: {intermediate_f1 * 100:.2f}%')
    print()

    results.append({
        'Real': row['issue_area'],
        'Previsto': normalized_result,
        'Correto': is_correct
    })

final_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
final_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
final_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f'Acurácia final: {correct_count / total_count * 100:.2f}%')
print(f'Precisão final: {final_precision * 100:.2f}%')
print(f'Recall final: {final_recall * 100:.2f}%')
print(f'F1-score final: {final_f1 * 100:.2f}%')

unique_labels = list(set(y_true + y_pred))
unique_labels.sort()

classification_report_str = classification_report(y_true, y_pred, labels=unique_labels)
print(classification_report_str)

report_dict = classification_report(y_true, y_pred, labels=unique_labels, output_dict=True)
report_df = pd.DataFrame(report_dict).transpose()

report_csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classification_report_descricoes.csv'
report_excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classification_report_descricoes.xlsx'

report_df.to_csv(report_csv_path, index=True)
report_df.to_excel(report_excel_path, index=True)

print(f'Relatório de classificação salvo em {report_csv_path} e {report_excel_path}')

results_df = pd.DataFrame(results)

csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classificacoes_descricoes.csv'
excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classificacoes_descricoes.xlsx'

results_df.to_csv(csv_path, index=False)
results_df.to_excel(excel_path, index=False)

print(f'Resultados salvos em {csv_path} e {excel_path}')
# Out:
# Real: INTIMACAO-NEGATIVA, Previsto: INTIMACAO-NEGATIVA, Correto: True
# Progresso: 1/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 3/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 4/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 5/346
# Acurácia até agora: 80.00%
# Precisão até agora: 80.00%
# Recall até agora: 80.00%
# F1-score até agora: 80.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 6/346
# Acurácia até agora: 83.33%
# Precisão até agora: 83.33%
# Recall até agora: 83.33%
# F1-score até agora: 83.33%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 7/346
# Acurácia até agora: 85.71%
# Precisão até agora: 85.71%
# Recall até agora: 85.71%
# F1-score até agora: 85.71%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 8/346
# Acurácia até agora: 87.50%
# Precisão até agora: 87.50%
# Recall até agora: 87.50%
# F1-score até agora: 87.50%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 9/346
# Acurácia até agora: 88.89%
# Precisão até agora: 88.89%
# Recall até agora: 88.89%
# F1-score até agora: 88.89%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 10/346
# Acurácia até agora: 90.00%
# Precisão até agora: 90.00%
# Recall até agora: 90.00%
# F1-score até agora: 90.00%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 11/346
# Acurácia até agora: 81.82%
# Precisão até agora: 81.82%
# Recall até agora: 81.82%
# F1-score até agora: 81.82%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: DISSOLUCAO-DE-CONDOMINIO, Correto: True
# Progresso: 12/346
# Acurácia até agora: 83.33%
# Precisão até agora: 83.33%
# Recall até agora: 83.33%
# F1-score até agora: 83.33%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 13/346
# Acurácia até agora: 84.62%
# Precisão até agora: 84.62%
# Recall até agora: 84.62%
# F1-score até agora: 84.62%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 14/346
# Acurácia até agora: 85.71%
# Precisão até agora: 85.71%
# Recall até agora: 85.71%
# F1-score até agora: 85.71%
#
# Real: IMPUGNACAO, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 15/346
# Acurácia até agora: 80.00%
# Precisão até agora: 86.67%
# Recall até agora: 80.00%
# F1-score até agora: 82.67%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 16/346
# Acurácia até agora: 81.25%
# Precisão até agora: 87.50%
# Recall até agora: 81.25%
# F1-score até agora: 83.75%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: PROGRESSAO-DE-REGIME, Correto: False
# Progresso: 17/346
# Acurácia até agora: 76.47%
# Precisão até agora: 88.24%
# Recall até agora: 76.47%
# F1-score até agora: 80.78%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 18/346
# Acurácia até agora: 77.78%
# Precisão até agora: 88.89%
# Recall até agora: 77.78%
# F1-score até agora: 82.01%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 19/346
# Acurácia até agora: 78.95%
# Precisão até agora: 89.47%
# Recall até agora: 78.95%
# F1-score até agora: 82.96%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 20/346
# Acurácia até agora: 80.00%
# Precisão até agora: 90.00%
# Recall até agora: 80.00%
# F1-score até agora: 83.81%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 21/346
# Acurácia até agora: 80.95%
# Precisão até agora: 90.48%
# Recall até agora: 80.95%
# F1-score até agora: 84.66%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 22/346
# Acurácia até agora: 81.82%
# Precisão até agora: 90.91%
# Recall até agora: 81.82%
# F1-score até agora: 85.35%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 23/346
# Acurácia até agora: 82.61%
# Precisão até agora: 91.30%
# Recall até agora: 82.61%
# F1-score até agora: 85.99%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 24/346
# Acurácia até agora: 83.33%
# Precisão até agora: 91.67%
# Recall até agora: 83.33%
# F1-score até agora: 86.57%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 25/346
# Acurácia até agora: 84.00%
# Precisão até agora: 92.00%
# Recall até agora: 84.00%
# F1-score até agora: 87.11%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 26/346
# Acurácia até agora: 84.62%
# Precisão até agora: 92.31%
# Recall até agora: 84.62%
# F1-score até agora: 87.61%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: OFICIOS, Correto: False
# Progresso: 27/346
# Acurácia até agora: 81.48%
# Precisão até agora: 86.42%
# Recall até agora: 81.48%
# F1-score até agora: 82.88%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 28/346
# Acurácia até agora: 82.14%
# Precisão até agora: 86.90%
# Recall até agora: 82.14%
# F1-score até agora: 83.49%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 29/346
# Acurácia até agora: 82.76%
# Precisão até agora: 87.36%
# Recall até agora: 82.76%
# F1-score até agora: 84.06%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 30/346
# Acurácia até agora: 83.33%
# Precisão até agora: 87.78%
# Recall até agora: 83.33%
# F1-score até agora: 84.59%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 31/346
# Acurácia até agora: 83.87%
# Precisão até agora: 88.17%
# Recall até agora: 83.87%
# F1-score até agora: 85.09%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 32/346
# Acurácia até agora: 84.38%
# Precisão até agora: 88.54%
# Recall até agora: 84.38%
# F1-score até agora: 85.56%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 33/346
# Acurácia até agora: 84.85%
# Precisão até agora: 88.89%
# Recall até agora: 84.85%
# F1-score até agora: 85.99%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 34/346
# Acurácia até agora: 85.29%
# Precisão até agora: 89.22%
# Recall até agora: 85.29%
# F1-score até agora: 86.41%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 35/346
# Acurácia até agora: 85.71%
# Precisão até agora: 89.52%
# Recall até agora: 85.71%
# F1-score até agora: 86.79%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 36/346
# Acurácia até agora: 86.11%
# Precisão até agora: 89.58%
# Recall até agora: 86.11%
# F1-score até agora: 87.08%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 37/346
# Acurácia até agora: 86.49%
# Precisão até agora: 89.86%
# Recall até agora: 86.49%
# F1-score até agora: 87.46%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 38/346
# Acurácia até agora: 86.84%
# Precisão até agora: 90.13%
# Recall até agora: 86.84%
# F1-score até agora: 87.79%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 39/346
# Acurácia até agora: 87.18%
# Precisão até agora: 90.26%
# Recall até agora: 87.18%
# F1-score até agora: 88.06%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 40/346
# Acurácia até agora: 87.50%
# Precisão até agora: 90.50%
# Recall até agora: 87.50%
# F1-score até agora: 88.38%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 41/346
# Acurácia até agora: 87.80%
# Precisão até agora: 90.73%
# Recall até agora: 87.80%
# F1-score até agora: 88.66%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 42/346
# Acurácia até agora: 88.10%
# Precisão até agora: 90.95%
# Recall até agora: 88.10%
# F1-score até agora: 88.93%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 43/346
# Acurácia até agora: 88.37%
# Precisão até agora: 91.16%
# Recall até agora: 88.37%
# F1-score até agora: 89.19%
#
# Real: PROGRESSAO-DE-REGIME, Previsto: PROGRESSAO-DE-REGIME, Correto: True
# Progresso: 44/346
# Acurácia até agora: 88.64%
# Precisão até agora: 90.23%
# Recall até agora: 88.64%
# F1-score até agora: 88.68%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 45/346
# Acurácia até agora: 86.67%
# Precisão até agora: 89.89%
# Recall até agora: 86.67%
# F1-score até agora: 87.45%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 46/346
# Acurácia até agora: 86.96%
# Precisão até agora: 90.22%
# Recall até agora: 86.96%
# F1-score até agora: 87.78%
#
# Real: INDULTO-COMUTACAO, Previsto: CONSIGNACAO-EM-PAGAMENTO, Correto: False
# Progresso: 47/346
# Acurácia até agora: 85.11%
# Precisão até agora: 90.43%
# Recall até agora: 85.11%
# F1-score até agora: 86.63%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: USUCAPIAO, Correto: False
# Progresso: 48/346
# Acurácia até agora: 83.33%
# Precisão até agora: 90.62%
# Recall até agora: 83.33%
# F1-score até agora: 85.52%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 49/346
# Acurácia até agora: 83.67%
# Precisão até agora: 90.82%
# Recall até agora: 83.67%
# F1-score até agora: 85.82%
#
# Real: IMPUGNACAO, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 50/346
# Acurácia até agora: 82.00%
# Precisão até agora: 91.00%
# Recall até agora: 82.00%
# F1-score até agora: 84.92%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 51/346
# Acurácia até agora: 82.35%
# Precisão até agora: 91.18%
# Recall até agora: 82.35%
# F1-score até agora: 85.22%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 52/346
# Acurácia até agora: 82.69%
# Precisão até agora: 91.35%
# Recall até agora: 82.69%
# F1-score até agora: 85.50%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 53/346
# Acurácia até agora: 83.02%
# Precisão até agora: 91.51%
# Recall até agora: 83.02%
# F1-score até agora: 85.80%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 54/346
# Acurácia até agora: 83.33%
# Precisão até agora: 91.67%
# Recall até agora: 83.33%
# F1-score até agora: 86.06%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 55/346
# Acurácia até agora: 83.64%
# Precisão até agora: 91.82%
# Recall até agora: 83.64%
# F1-score até agora: 86.32%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 56/346
# Acurácia até agora: 83.93%
# Precisão até agora: 91.96%
# Recall até agora: 83.93%
# F1-score até agora: 86.58%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 57/346
# Acurácia até agora: 84.21%
# Precisão até agora: 92.16%
# Recall até agora: 84.21%
# F1-score até agora: 86.85%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 58/346
# Acurácia até agora: 84.48%
# Precisão até agora: 92.30%
# Recall até agora: 84.48%
# F1-score até agora: 87.10%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 59/346
# Acurácia até agora: 84.75%
# Precisão até agora: 92.43%
# Recall até agora: 84.75%
# F1-score até agora: 87.32%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 60/346
# Acurácia até agora: 85.00%
# Precisão até agora: 92.56%
# Recall até agora: 85.00%
# F1-score até agora: 87.53%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 61/346
# Acurácia até agora: 85.25%
# Precisão até agora: 92.68%
# Recall até agora: 85.25%
# F1-score até agora: 87.74%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 62/346
# Acurácia até agora: 85.48%
# Precisão até agora: 92.80%
# Recall até agora: 85.48%
# F1-score até agora: 87.94%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 63/346
# Acurácia até agora: 85.71%
# Precisão até agora: 92.91%
# Recall até agora: 85.71%
# F1-score até agora: 88.13%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 64/346
# Acurácia até agora: 85.94%
# Precisão até agora: 93.02%
# Recall até agora: 85.94%
# F1-score até agora: 88.32%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 65/346
# Acurácia até agora: 86.15%
# Precisão até agora: 93.13%
# Recall até agora: 86.15%
# F1-score até agora: 88.50%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 66/346
# Acurácia até agora: 86.36%
# Precisão até agora: 92.47%
# Recall até agora: 86.36%
# F1-score até agora: 88.17%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 67/346
# Acurácia até agora: 86.57%
# Precisão até agora: 92.59%
# Recall até agora: 86.57%
# F1-score até agora: 88.44%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 68/346
# Acurácia até agora: 85.29%
# Precisão até agora: 91.36%
# Recall até agora: 85.29%
# F1-score até agora: 87.13%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 69/346
# Acurácia até agora: 85.51%
# Precisão até agora: 91.48%
# Recall até agora: 85.51%
# F1-score até agora: 87.31%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 70/346
# Acurácia até agora: 85.71%
# Precisão até agora: 91.60%
# Recall até agora: 85.71%
# F1-score até agora: 87.49%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 71/346
# Acurácia até agora: 85.92%
# Precisão até agora: 91.75%
# Recall até agora: 85.92%
# F1-score até agora: 87.69%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 72/346
# Acurácia até agora: 86.11%
# Precisão até agora: 91.86%
# Recall até agora: 86.11%
# F1-score até agora: 87.86%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 73/346
# Acurácia até agora: 86.30%
# Precisão até agora: 91.96%
# Recall até agora: 86.30%
# F1-score até agora: 88.03%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 74/346
# Acurácia até agora: 86.49%
# Precisão até agora: 92.07%
# Recall até agora: 86.49%
# F1-score até agora: 88.28%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 75/346
# Acurácia até agora: 86.67%
# Precisão até agora: 92.13%
# Recall até agora: 86.67%
# F1-score até agora: 88.42%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 76/346
# Acurácia até agora: 86.84%
# Precisão até agora: 92.24%
# Recall até agora: 86.84%
# F1-score até agora: 88.58%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 77/346
# Acurácia até agora: 85.71%
# Precisão até agora: 91.04%
# Recall até agora: 85.71%
# F1-score até agora: 87.59%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 78/346
# Acurácia até agora: 85.90%
# Precisão até agora: 91.15%
# Recall até agora: 85.90%
# F1-score até agora: 87.75%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 79/346
# Acurácia até agora: 86.08%
# Precisão até agora: 91.27%
# Recall até agora: 86.08%
# F1-score até agora: 87.90%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 80/346
# Acurácia até agora: 86.25%
# Precisão até agora: 91.38%
# Recall até agora: 86.25%
# F1-score até agora: 88.06%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 81/346
# Acurácia até agora: 85.19%
# Precisão até agora: 90.42%
# Recall até agora: 85.19%
# F1-score até agora: 86.95%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 82/346
# Acurácia até agora: 85.37%
# Precisão até agora: 90.51%
# Recall até agora: 85.37%
# F1-score até agora: 87.10%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 83/346
# Acurácia até agora: 85.54%
# Precisão até agora: 90.43%
# Recall até agora: 85.54%
# F1-score até agora: 87.17%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 84/346
# Acurácia até agora: 85.71%
# Precisão até agora: 90.53%
# Recall até agora: 85.71%
# F1-score até agora: 87.32%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 85/346
# Acurácia até agora: 85.88%
# Precisão até agora: 90.64%
# Recall até agora: 85.88%
# F1-score até agora: 87.47%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 86/346
# Acurácia até agora: 86.05%
# Precisão até agora: 90.75%
# Recall até agora: 86.05%
# F1-score até agora: 87.64%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 87/346
# Acurácia até agora: 86.21%
# Precisão até agora: 90.85%
# Recall até agora: 86.21%
# F1-score até agora: 87.79%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 88/346
# Acurácia até agora: 86.36%
# Precisão até agora: 90.94%
# Recall até agora: 86.36%
# F1-score até agora: 87.92%
#
# Real: SAIDA-TEMPORARIA, Previsto: SAIDA-TEMPORARIA, Correto: True
# Progresso: 89/346
# Acurácia até agora: 86.52%
# Precisão até agora: 91.04%
# Recall até agora: 86.52%
# F1-score até agora: 88.05%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 90/346
# Acurácia até agora: 86.67%
# Precisão até agora: 91.14%
# Recall até agora: 86.67%
# F1-score até agora: 88.19%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 91/346
# Acurácia até agora: 86.81%
# Precisão até agora: 91.24%
# Recall até agora: 86.81%
# F1-score até agora: 88.32%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 92/346
# Acurácia até agora: 86.96%
# Precisão até agora: 91.33%
# Recall até agora: 86.96%
# F1-score até agora: 88.45%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 93/346
# Acurácia até agora: 87.10%
# Precisão até agora: 91.41%
# Recall até agora: 87.10%
# F1-score até agora: 88.57%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 94/346
# Acurácia até agora: 87.23%
# Precisão até agora: 91.50%
# Recall até agora: 87.23%
# F1-score até agora: 88.69%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 95/346
# Acurácia até agora: 87.37%
# Precisão até agora: 91.59%
# Recall até agora: 87.37%
# F1-score até agora: 88.84%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 96/346
# Acurácia até agora: 87.50%
# Precisão até agora: 91.67%
# Recall até agora: 87.50%
# F1-score até agora: 88.95%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 97/346
# Acurácia até agora: 87.63%
# Precisão até agora: 91.76%
# Recall até agora: 87.63%
# F1-score até agora: 89.09%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 98/346
# Acurácia até agora: 87.76%
# Precisão até agora: 91.84%
# Recall até agora: 87.76%
# F1-score até agora: 89.21%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 99/346
# Acurácia até agora: 87.88%
# Precisão até agora: 91.92%
# Recall até agora: 87.88%
# F1-score até agora: 89.32%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EMBARGOS, Correto: False
# Progresso: 100/346
# Acurácia até agora: 87.00%
# Precisão até agora: 91.00%
# Recall até agora: 87.00%
# F1-score até agora: 88.22%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 101/346
# Acurácia até agora: 87.13%
# Precisão até agora: 91.09%
# Recall até agora: 87.13%
# F1-score até agora: 88.34%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 102/346
# Acurácia até agora: 87.25%
# Precisão até agora: 91.18%
# Recall até agora: 87.25%
# F1-score até agora: 88.47%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 103/346
# Acurácia até agora: 87.38%
# Precisão até agora: 91.26%
# Recall até agora: 87.38%
# F1-score até agora: 88.58%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: REGISTRO-CIVIL, Correto: False
# Progresso: 104/346
# Acurácia até agora: 86.54%
# Precisão até agora: 90.52%
# Recall até agora: 86.54%
# F1-score até agora: 87.65%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: True
# Progresso: 105/346
# Acurácia até agora: 86.67%
# Precisão até agora: 90.61%
# Recall até agora: 86.67%
# F1-score até agora: 87.77%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 106/346
# Acurácia até agora: 86.79%
# Precisão até agora: 90.69%
# Recall até agora: 86.79%
# F1-score até agora: 87.88%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 107/346
# Acurácia até agora: 86.92%
# Precisão até agora: 90.47%
# Recall até agora: 86.92%
# F1-score até agora: 87.81%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 108/346
# Acurácia até agora: 87.04%
# Precisão até agora: 90.55%
# Recall até agora: 87.04%
# F1-score até agora: 87.92%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 109/346
# Acurácia até agora: 87.16%
# Precisão até agora: 90.63%
# Recall até agora: 87.16%
# F1-score até agora: 88.03%
#
# Real: EMBARGOS, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 110/346
# Acurácia até agora: 86.36%
# Precisão até agora: 90.48%
# Recall até agora: 86.36%
# F1-score até agora: 87.50%
#
# Real: IMPUGNACAO, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 111/346
# Acurácia até agora: 85.59%
# Precisão até agora: 90.47%
# Recall até agora: 85.59%
# F1-score até agora: 87.00%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 112/346
# Acurácia até agora: 85.71%
# Precisão até agora: 90.56%
# Recall até agora: 85.71%
# F1-score até agora: 87.13%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 113/346
# Acurácia até agora: 85.84%
# Precisão até agora: 90.62%
# Recall até agora: 85.84%
# F1-score até agora: 87.24%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 114/346
# Acurácia até agora: 85.96%
# Precisão até agora: 90.71%
# Recall até agora: 85.96%
# F1-score até agora: 87.35%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 115/346
# Acurácia até agora: 86.09%
# Precisão até agora: 90.79%
# Recall até agora: 86.09%
# F1-score até agora: 87.48%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 116/346
# Acurácia até agora: 86.21%
# Precisão até agora: 90.87%
# Recall até agora: 86.21%
# F1-score até agora: 87.59%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 117/346
# Acurácia até agora: 86.32%
# Precisão até agora: 90.94%
# Recall até agora: 86.32%
# F1-score até agora: 87.70%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 118/346
# Acurácia até agora: 86.44%
# Precisão até agora: 91.02%
# Recall até agora: 86.44%
# F1-score até agora: 87.80%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 119/346
# Acurácia até agora: 86.55%
# Precisão até agora: 91.09%
# Recall até agora: 86.55%
# F1-score até agora: 87.91%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 120/346
# Acurácia até agora: 86.67%
# Precisão até agora: 91.17%
# Recall até agora: 86.67%
# F1-score até agora: 88.01%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 121/346
# Acurácia até agora: 86.78%
# Precisão até agora: 91.24%
# Recall até agora: 86.78%
# F1-score até agora: 88.13%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 122/346
# Acurácia até agora: 86.07%
# Precisão até agora: 90.03%
# Recall até agora: 86.07%
# F1-score até agora: 87.22%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 123/346
# Acurácia até agora: 86.18%
# Precisão até agora: 90.11%
# Recall até agora: 86.18%
# F1-score até agora: 87.33%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 124/346
# Acurácia até agora: 86.29%
# Precisão até agora: 90.19%
# Recall até agora: 86.29%
# F1-score até agora: 87.43%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 125/346
# Acurácia até agora: 86.40%
# Precisão até agora: 90.27%
# Recall até agora: 86.40%
# F1-score até agora: 87.53%
#
# Real: CONSIGNACAO-EM-PAGAMENTO, Previsto: CONSIGNACAO-EM-PAGAMENTO, Correto: True
# Progresso: 126/346
# Acurácia até agora: 86.51%
# Precisão até agora: 89.95%
# Recall até agora: 86.51%
# F1-score até agora: 87.37%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 127/346
# Acurácia até agora: 86.61%
# Precisão até agora: 90.03%
# Recall até agora: 86.61%
# F1-score até agora: 87.47%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 128/346
# Acurácia até agora: 85.94%
# Precisão até agora: 89.59%
# Recall até agora: 85.94%
# F1-score até agora: 86.81%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 129/346
# Acurácia até agora: 86.05%
# Precisão até agora: 89.67%
# Recall até agora: 86.05%
# F1-score até agora: 86.91%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 130/346
# Acurácia até agora: 86.15%
# Precisão até agora: 89.75%
# Recall até agora: 86.15%
# F1-score até agora: 87.02%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 131/346
# Acurácia até agora: 86.26%
# Precisão até agora: 89.83%
# Recall até agora: 86.26%
# F1-score até agora: 87.12%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 132/346
# Acurácia até agora: 86.36%
# Precisão até agora: 89.91%
# Recall até agora: 86.36%
# F1-score até agora: 87.22%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 133/346
# Acurácia até agora: 86.47%
# Precisão até agora: 89.78%
# Recall até agora: 86.47%
# F1-score até agora: 87.20%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 134/346
# Acurácia até agora: 86.57%
# Precisão até agora: 89.83%
# Recall até agora: 86.57%
# F1-score até agora: 87.29%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EMBARGOS, Correto: False
# Progresso: 135/346
# Acurácia até agora: 85.93%
# Precisão até agora: 89.23%
# Recall até agora: 85.93%
# F1-score até agora: 86.46%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 136/346
# Acurácia até agora: 86.03%
# Precisão até agora: 89.31%
# Recall até agora: 86.03%
# F1-score até agora: 86.56%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 137/346
# Acurácia até agora: 86.13%
# Precisão até agora: 89.38%
# Recall até agora: 86.13%
# F1-score até agora: 86.66%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 138/346
# Acurácia até agora: 86.23%
# Precisão até agora: 89.45%
# Recall até agora: 86.23%
# F1-score até agora: 86.77%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 139/346
# Acurácia até agora: 86.33%
# Precisão até agora: 89.52%
# Recall até agora: 86.33%
# F1-score até agora: 86.86%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 140/346
# Acurácia até agora: 86.43%
# Precisão até agora: 89.59%
# Recall até agora: 86.43%
# F1-score até agora: 86.95%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 141/346
# Acurácia até agora: 86.52%
# Precisão até agora: 89.66%
# Recall até agora: 86.52%
# F1-score até agora: 87.04%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 142/346
# Acurácia até agora: 86.62%
# Precisão até agora: 89.73%
# Recall até agora: 86.62%
# F1-score até agora: 87.13%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 143/346
# Acurácia até agora: 86.71%
# Precisão até agora: 89.67%
# Recall até agora: 86.71%
# F1-score até agora: 87.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 144/346
# Acurácia até agora: 86.81%
# Precisão até agora: 89.74%
# Recall até agora: 86.81%
# F1-score até agora: 87.25%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 145/346
# Acurácia até agora: 86.90%
# Precisão até agora: 89.81%
# Recall até agora: 86.90%
# F1-score até agora: 87.34%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 146/346
# Acurácia até agora: 86.99%
# Precisão até agora: 89.87%
# Recall até agora: 86.99%
# F1-score até agora: 87.42%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: INDULTO-COMUTACAO, Correto: False
# Progresso: 147/346
# Acurácia até agora: 86.39%
# Precisão até agora: 89.26%
# Recall até agora: 86.39%
# F1-score até agora: 86.79%
#
# Real: INTIMACAO-NEGATIVA, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: False
# Progresso: 148/346
# Acurácia até agora: 85.81%
# Precisão até agora: 88.80%
# Recall até agora: 85.81%
# F1-score até agora: 86.13%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 149/346
# Acurácia até agora: 85.91%
# Precisão até agora: 88.85%
# Recall até agora: 85.91%
# F1-score até agora: 86.22%
#
# Real: EMBARGOS, Previsto: IMPUGNACAO, Correto: False
# Progresso: 150/346
# Acurácia até agora: 85.33%
# Precisão até agora: 88.04%
# Recall até agora: 85.33%
# F1-score até agora: 85.59%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 151/346
# Acurácia até agora: 85.43%
# Precisão até agora: 88.12%
# Recall até agora: 85.43%
# F1-score até agora: 85.69%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 152/346
# Acurácia até agora: 85.53%
# Precisão até agora: 88.15%
# Recall até agora: 85.53%
# F1-score até agora: 85.77%
#
# Real: EMBARGOS, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 153/346
# Acurácia até agora: 84.97%
# Precisão até agora: 88.13%
# Recall até agora: 84.97%
# F1-score até agora: 85.46%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 154/346
# Acurácia até agora: 84.42%
# Precisão até agora: 87.72%
# Recall até agora: 84.42%
# F1-score até agora: 84.86%
#
# Real: IMPUGNACAO, Previsto: PROGRESSAO-DE-REGIME, Correto: False
# Progresso: 155/346
# Acurácia até agora: 83.87%
# Precisão até agora: 87.65%
# Recall até agora: 83.87%
# F1-score até agora: 84.46%
#
# Real: APELACAO, Previsto: SAIDA-TEMPORARIA, Correto: False
# Progresso: 156/346
# Acurácia até agora: 83.33%
# Precisão até agora: 87.25%
# Recall até agora: 83.33%
# F1-score até agora: 83.96%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 157/346
# Acurácia até agora: 83.44%
# Precisão até agora: 87.33%
# Recall até agora: 83.44%
# F1-score até agora: 84.07%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 158/346
# Acurácia até agora: 83.54%
# Precisão até agora: 87.42%
# Recall até agora: 83.54%
# F1-score até agora: 84.17%
#
# Real: IMPUGNACAO, Previsto: USUCAPIAO, Correto: False
# Progresso: 159/346
# Acurácia até agora: 83.02%
# Precisão até agora: 87.18%
# Recall até agora: 83.02%
# F1-score até agora: 83.67%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 160/346
# Acurácia até agora: 83.12%
# Precisão até agora: 87.26%
# Recall até agora: 83.12%
# F1-score até agora: 83.78%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 161/346
# Acurácia até agora: 83.23%
# Precisão até agora: 87.34%
# Recall até agora: 83.23%
# F1-score até agora: 83.88%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 162/346
# Acurácia até agora: 83.33%
# Precisão até agora: 87.42%
# Recall até agora: 83.33%
# F1-score até agora: 83.98%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 163/346
# Acurácia até agora: 83.44%
# Precisão até agora: 87.49%
# Recall até agora: 83.44%
# F1-score até agora: 84.09%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 164/346
# Acurácia até agora: 83.54%
# Precisão até agora: 87.57%
# Recall até agora: 83.54%
# F1-score até agora: 84.19%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 165/346
# Acurácia até agora: 83.03%
# Precisão até agora: 87.22%
# Recall até agora: 83.03%
# F1-score até agora: 83.75%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 166/346
# Acurácia até agora: 82.53%
# Precisão até agora: 86.94%
# Recall até agora: 82.53%
# F1-score até agora: 83.13%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 167/346
# Acurácia até agora: 82.63%
# Precisão até agora: 87.02%
# Recall até agora: 82.63%
# F1-score até agora: 83.23%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 168/346
# Acurácia até agora: 82.74%
# Precisão até agora: 87.09%
# Recall até agora: 82.74%
# F1-score até agora: 83.33%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 169/346
# Acurácia até agora: 82.25%
# Precisão até agora: 87.01%
# Recall até agora: 82.25%
# F1-score até agora: 82.79%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 170/346
# Acurácia até agora: 82.35%
# Precisão até agora: 87.07%
# Recall até agora: 82.35%
# F1-score até agora: 82.88%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 171/346
# Acurácia até agora: 82.46%
# Precisão até agora: 87.14%
# Recall até agora: 82.46%
# F1-score até agora: 82.99%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 172/346
# Acurácia até agora: 82.56%
# Precisão até agora: 87.19%
# Recall até agora: 82.56%
# F1-score até agora: 83.08%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 173/346
# Acurácia até agora: 82.66%
# Precisão até agora: 87.27%
# Recall até agora: 82.66%
# F1-score até agora: 83.19%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: UNIFICACAO-DE-PENAS, Correto: True
# Progresso: 174/346
# Acurácia até agora: 82.76%
# Precisão até agora: 87.92%
# Recall até agora: 82.76%
# F1-score até agora: 83.48%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 175/346
# Acurácia até agora: 82.86%
# Precisão até agora: 87.99%
# Recall até agora: 82.86%
# F1-score até agora: 83.58%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 176/346
# Acurácia até agora: 82.95%
# Precisão até agora: 88.05%
# Recall até agora: 82.95%
# F1-score até agora: 83.67%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 177/346
# Acurácia até agora: 83.05%
# Precisão até agora: 88.00%
# Recall até agora: 83.05%
# F1-score até agora: 83.71%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 178/346
# Acurácia até agora: 82.58%
# Precisão até agora: 87.89%
# Recall até agora: 82.58%
# F1-score até agora: 83.46%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 179/346
# Acurácia até agora: 82.68%
# Precisão até agora: 87.96%
# Recall até agora: 82.68%
# F1-score até agora: 83.55%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 180/346
# Acurácia até agora: 82.78%
# Precisão até agora: 88.04%
# Recall até agora: 82.78%
# F1-score até agora: 83.65%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 181/346
# Acurácia até agora: 82.87%
# Precisão até agora: 88.10%
# Recall até agora: 82.87%
# F1-score até agora: 83.74%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 182/346
# Acurácia até agora: 82.97%
# Precisão até agora: 88.17%
# Recall até agora: 82.97%
# F1-score até agora: 83.97%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 183/346
# Acurácia até agora: 83.06%
# Precisão até agora: 88.23%
# Recall até agora: 83.06%
# F1-score até agora: 84.06%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 184/346
# Acurácia até agora: 83.15%
# Precisão até agora: 88.30%
# Recall até agora: 83.15%
# F1-score até agora: 84.14%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 185/346
# Acurácia até agora: 83.24%
# Precisão até agora: 88.36%
# Recall até agora: 83.24%
# F1-score até agora: 84.23%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 186/346
# Acurácia até agora: 83.33%
# Precisão até agora: 88.42%
# Recall até agora: 83.33%
# F1-score até agora: 84.31%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 187/346
# Acurácia até agora: 83.42%
# Precisão até agora: 88.48%
# Recall até agora: 83.42%
# F1-score até agora: 84.40%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 188/346
# Acurácia até agora: 83.51%
# Precisão até agora: 88.55%
# Recall até agora: 83.51%
# F1-score até agora: 84.49%
#
# Real: EMBARGOS, Previsto: IMPUGNACAO, Correto: False
# Progresso: 189/346
# Acurácia até agora: 83.07%
# Precisão até agora: 87.95%
# Recall até agora: 83.07%
# F1-score até agora: 84.01%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 190/346
# Acurácia até agora: 83.16%
# Precisão até agora: 88.01%
# Recall até agora: 83.16%
# F1-score até agora: 84.09%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 191/346
# Acurácia até agora: 83.25%
# Precisão até agora: 88.08%
# Recall até agora: 83.25%
# F1-score até agora: 84.18%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 192/346
# Acurácia até agora: 83.33%
# Precisão até agora: 88.06%
# Recall até agora: 83.33%
# F1-score até agora: 84.22%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 193/346
# Acurácia até agora: 83.42%
# Precisão até agora: 88.12%
# Recall até agora: 83.42%
# F1-score até agora: 84.30%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 194/346
# Acurácia até agora: 83.51%
# Precisão até agora: 88.18%
# Recall até agora: 83.51%
# F1-score até agora: 84.39%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 195/346
# Acurácia até agora: 83.59%
# Precisão até agora: 88.22%
# Recall até agora: 83.59%
# F1-score até agora: 84.46%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 196/346
# Acurácia até agora: 83.67%
# Precisão até agora: 88.21%
# Recall até agora: 83.67%
# F1-score até agora: 84.51%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 197/346
# Acurácia até agora: 83.76%
# Precisão até agora: 88.27%
# Recall até agora: 83.76%
# F1-score até agora: 84.59%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 198/346
# Acurácia até agora: 83.33%
# Precisão até agora: 88.18%
# Recall até agora: 83.33%
# F1-score até agora: 84.35%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 199/346
# Acurácia até agora: 83.42%
# Precisão até agora: 88.24%
# Recall até agora: 83.42%
# F1-score até agora: 84.43%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 200/346
# Acurácia até agora: 83.50%
# Precisão até agora: 88.30%
# Recall até agora: 83.50%
# F1-score até agora: 84.51%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 201/346
# Acurácia até agora: 83.08%
# Precisão até agora: 88.21%
# Recall até agora: 83.08%
# F1-score até agora: 84.27%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 202/346
# Acurácia até agora: 83.17%
# Precisão até agora: 88.27%
# Recall até agora: 83.17%
# F1-score até agora: 84.35%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 203/346
# Acurácia até agora: 83.25%
# Precisão até agora: 88.27%
# Recall até agora: 83.25%
# F1-score até agora: 84.40%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 204/346
# Acurácia até agora: 83.33%
# Precisão até agora: 88.33%
# Recall até agora: 83.33%
# F1-score até agora: 84.48%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 205/346
# Acurácia até agora: 83.41%
# Precisão até agora: 88.38%
# Recall até agora: 83.41%
# F1-score até agora: 84.56%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 206/346
# Acurácia até agora: 83.50%
# Precisão até agora: 88.45%
# Recall até agora: 83.50%
# F1-score até agora: 84.64%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 207/346
# Acurácia até agora: 83.57%
# Precisão até agora: 88.51%
# Recall até agora: 83.57%
# F1-score até agora: 84.71%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 208/346
# Acurácia até agora: 83.65%
# Precisão até agora: 88.56%
# Recall até agora: 83.65%
# F1-score até agora: 84.79%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 209/346
# Acurácia até agora: 83.73%
# Precisão até agora: 88.61%
# Recall até agora: 83.73%
# F1-score até agora: 84.86%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 210/346
# Acurácia até agora: 83.81%
# Precisão até agora: 88.67%
# Recall até agora: 83.81%
# F1-score até agora: 84.93%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 211/346
# Acurácia até agora: 83.89%
# Precisão até agora: 88.73%
# Recall até agora: 83.89%
# F1-score até agora: 85.01%
#
# Real: EMBARGOS, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 212/346
# Acurácia até agora: 83.49%
# Precisão até agora: 88.54%
# Recall até agora: 83.49%
# F1-score até agora: 84.66%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 213/346
# Acurácia até agora: 83.57%
# Precisão até agora: 88.61%
# Recall até agora: 83.57%
# F1-score até agora: 84.74%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 214/346
# Acurácia até agora: 83.64%
# Precisão até agora: 88.67%
# Recall até agora: 83.64%
# F1-score até agora: 84.82%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 215/346
# Acurácia até agora: 83.72%
# Precisão até agora: 88.73%
# Recall até agora: 83.72%
# F1-score até agora: 84.89%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 216/346
# Acurácia até agora: 83.80%
# Precisão até agora: 88.72%
# Recall até agora: 83.80%
# F1-score até agora: 84.94%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 217/346
# Acurácia até agora: 83.87%
# Precisão até agora: 88.77%
# Recall até agora: 83.87%
# F1-score até agora: 85.01%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 218/346
# Acurácia até agora: 83.94%
# Precisão até agora: 88.82%
# Recall até agora: 83.94%
# F1-score até agora: 85.08%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 219/346
# Acurácia até agora: 84.02%
# Precisão até agora: 88.87%
# Recall até agora: 84.02%
# F1-score até agora: 85.15%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 220/346
# Acurácia até agora: 84.09%
# Precisão até agora: 88.92%
# Recall até agora: 84.09%
# F1-score até agora: 85.22%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 221/346
# Acurácia até agora: 83.71%
# Precisão até agora: 88.67%
# Recall até agora: 83.71%
# F1-score até agora: 84.74%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EMBARGOS, Correto: False
# Progresso: 222/346
# Acurácia até agora: 83.33%
# Precisão até agora: 88.26%
# Recall até agora: 83.33%
# F1-score até agora: 84.21%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 223/346
# Acurácia até agora: 83.41%
# Precisão até agora: 88.30%
# Recall até agora: 83.41%
# F1-score até agora: 84.28%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 224/346
# Acurácia até agora: 83.48%
# Precisão até agora: 88.35%
# Recall até agora: 83.48%
# F1-score até agora: 84.35%
#
# Real: CONTRARRAZOES-AO-AGRAVO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: True
# Progresso: 225/346
# Acurácia até agora: 83.56%
# Precisão até agora: 88.02%
# Recall até agora: 83.56%
# F1-score até agora: 84.09%
#
# Real: EMBARGOS, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 226/346
# Acurácia até agora: 83.19%
# Precisão até agora: 86.90%
# Recall até agora: 83.19%
# F1-score até agora: 83.73%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 227/346
# Acurácia até agora: 83.26%
# Precisão até agora: 86.96%
# Recall até agora: 83.26%
# F1-score até agora: 83.80%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 228/346
# Acurácia até agora: 83.33%
# Precisão até agora: 86.96%
# Recall até agora: 83.33%
# F1-score até agora: 83.85%
#
# Real: INTIMACAO-NEGATIVA, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: False
# Progresso: 229/346
# Acurácia até agora: 82.97%
# Precisão até agora: 86.74%
# Recall até agora: 82.97%
# F1-score até agora: 83.38%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 230/346
# Acurácia até agora: 83.04%
# Precisão até agora: 86.79%
# Recall até agora: 83.04%
# F1-score até agora: 83.45%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 231/346
# Acurácia até agora: 83.12%
# Precisão até agora: 86.80%
# Recall até agora: 83.12%
# F1-score até agora: 83.50%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 232/346
# Acurácia até agora: 83.19%
# Precisão até agora: 86.86%
# Recall até agora: 83.19%
# F1-score até agora: 83.57%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 233/346
# Acurácia até agora: 83.26%
# Precisão até agora: 86.91%
# Recall até agora: 83.26%
# F1-score até agora: 83.64%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 234/346
# Acurácia até agora: 83.33%
# Precisão até agora: 86.96%
# Recall até agora: 83.33%
# F1-score até agora: 83.71%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 235/346
# Acurácia até agora: 83.40%
# Precisão até agora: 87.02%
# Recall até agora: 83.40%
# F1-score até agora: 83.78%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 236/346
# Acurácia até agora: 83.47%
# Precisão até agora: 87.03%
# Recall até agora: 83.47%
# F1-score até agora: 83.83%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 237/346
# Acurácia até agora: 83.54%
# Precisão até agora: 87.10%
# Recall até agora: 83.54%
# F1-score até agora: 83.91%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 238/346
# Acurácia até agora: 83.19%
# Precisão até agora: 86.86%
# Recall até agora: 83.19%
# F1-score até agora: 83.48%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 239/346
# Acurácia até agora: 83.26%
# Precisão até agora: 86.92%
# Recall até agora: 83.26%
# F1-score até agora: 83.55%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 240/346
# Acurácia até agora: 83.33%
# Precisão até agora: 86.96%
# Recall até agora: 83.33%
# F1-score até agora: 83.61%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 241/346
# Acurácia até agora: 83.40%
# Precisão até agora: 87.01%
# Recall até agora: 83.40%
# F1-score até agora: 83.68%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 242/346
# Acurácia até agora: 83.47%
# Precisão até agora: 87.06%
# Recall até agora: 83.47%
# F1-score até agora: 83.74%
#
# Real: INDULTO-COMUTACAO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 243/346
# Acurácia até agora: 83.13%
# Precisão até agora: 86.61%
# Recall até agora: 83.13%
# F1-score até agora: 83.37%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 244/346
# Acurácia até agora: 83.20%
# Precisão até agora: 86.67%
# Recall até agora: 83.20%
# F1-score até agora: 83.43%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 245/346
# Acurácia até agora: 83.27%
# Precisão até agora: 86.72%
# Recall até agora: 83.27%
# F1-score até agora: 83.50%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 246/346
# Acurácia até agora: 83.33%
# Precisão até agora: 86.77%
# Recall até agora: 83.33%
# F1-score até agora: 83.57%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 247/346
# Acurácia até agora: 83.40%
# Precisão até agora: 86.83%
# Recall até agora: 83.40%
# F1-score até agora: 83.64%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 248/346
# Acurácia até agora: 83.47%
# Precisão até agora: 86.88%
# Recall até agora: 83.47%
# F1-score até agora: 83.71%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 249/346
# Acurácia até agora: 83.53%
# Precisão até agora: 86.94%
# Recall até agora: 83.53%
# F1-score até agora: 83.77%
#
# Real: IMPUGNACAO, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 250/346
# Acurácia até agora: 83.20%
# Precisão até agora: 86.80%
# Recall até agora: 83.20%
# F1-score até agora: 83.48%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 251/346
# Acurácia até agora: 83.27%
# Precisão até agora: 86.86%
# Recall até agora: 83.27%
# F1-score até agora: 83.55%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 252/346
# Acurácia até agora: 83.33%
# Precisão até agora: 86.91%
# Recall até agora: 83.33%
# F1-score até agora: 83.62%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 253/346
# Acurácia até agora: 83.40%
# Precisão até agora: 86.91%
# Recall até agora: 83.40%
# F1-score até agora: 83.66%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: AGRAVO, Correto: False
# Progresso: 254/346
# Acurácia até agora: 83.07%
# Precisão até agora: 86.59%
# Recall até agora: 83.07%
# F1-score até agora: 83.21%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 255/346
# Acurácia até agora: 82.75%
# Precisão até agora: 86.28%
# Recall até agora: 82.75%
# F1-score até agora: 82.87%
#
# ...
# Progresso: 279/346
# Acurácia até agora: 82.80%
# Precisão até agora: 86.69%
# Recall até agora: 82.80%
# F1-score até agora: 83.12%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 280/346
# Acurácia até agora: 82.86%
# Precisão até agora: 86.73%
# Recall até agora: 82.86%
# F1-score até agora: 83.18%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 281/346
# Acurácia até agora: 82.92%
# Precisão até agora: 86.78%
# Recall até agora: 82.92%
# F1-score até agora: 83.24%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 282/346
# Acurácia até agora: 82.98%
# Precisão até agora: 86.82%
# Recall até agora: 82.98%
# F1-score até agora: 83.29%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 283/346
# Acurácia até agora: 83.04%
# Precisão até agora: 87.00%
# Recall até agora: 83.04%
# F1-score até agora: 83.45%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 284/346
# Acurácia até agora: 83.10%
# Precisão até agora: 87.05%
# Recall até agora: 83.10%
# F1-score até agora: 83.51%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 285/346
# Acurácia até agora: 83.16%
# Precisão até agora: 87.10%
# Recall até agora: 83.16%
# F1-score até agora: 83.57%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: PROGRESSAO-DE-REGIME, Correto: False
# Progresso: 286/346
# Acurácia até agora: 82.87%
# Precisão até agora: 87.12%
# Recall até agora: 82.87%
# F1-score até agora: 83.41%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 287/346
# Acurácia até agora: 82.93%
# Precisão até agora: 87.17%
# Recall até agora: 82.93%
# F1-score até agora: 83.47%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 288/346
# Acurácia até agora: 82.99%
# Precisão até agora: 87.22%
# Recall até agora: 82.99%
# F1-score até agora: 83.53%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 289/346
# Acurácia até agora: 83.04%
# Precisão até agora: 87.26%
# Recall até agora: 83.04%
# F1-score até agora: 83.58%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 290/346
# Acurácia até agora: 82.76%
# Precisão até agora: 87.10%
# Recall até agora: 82.76%
# F1-score até agora: 83.24%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 291/346
# Acurácia até agora: 82.82%
# Precisão até agora: 87.15%
# Recall até agora: 82.82%
# F1-score até agora: 83.30%
#
# Real: INDULTO-COMUTACAO, Previsto: IMPUGNACAO, Correto: False
# Progresso: 292/346
# Acurácia até agora: 82.53%
# Precisão até agora: 86.77%
# Recall até agora: 82.53%
# F1-score até agora: 82.99%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 293/346
# Acurácia até agora: 82.59%
# Precisão até agora: 86.82%
# Recall até agora: 82.59%
# F1-score até agora: 83.05%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 294/346
# Acurácia até agora: 82.65%
# Precisão até agora: 86.85%
# Recall até agora: 82.65%
# F1-score até agora: 83.11%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 295/346
# Acurácia até agora: 82.71%
# Precisão até agora: 87.00%
# Recall até agora: 82.71%
# F1-score até agora: 83.25%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 296/346
# Acurácia até agora: 82.77%
# Precisão até agora: 87.05%
# Recall até agora: 82.77%
# F1-score até agora: 83.31%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 297/346
# Acurácia até agora: 82.83%
# Precisão até agora: 87.08%
# Recall até agora: 82.83%
# F1-score até agora: 83.36%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 298/346
# Acurácia até agora: 82.89%
# Precisão até agora: 87.13%
# Recall até agora: 82.89%
# F1-score até agora: 83.42%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 299/346
# Acurácia até agora: 82.94%
# Precisão até agora: 87.17%
# Recall até agora: 82.94%
# F1-score até agora: 83.47%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 300/346
# Acurácia até agora: 83.00%
# Precisão até agora: 87.22%
# Recall até agora: 83.00%
# F1-score até agora: 83.53%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 301/346
# Acurácia até agora: 83.06%
# Precisão até agora: 87.26%
# Recall até agora: 83.06%
# F1-score até agora: 83.58%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: DISSOLUCAO-DE-CONDOMINIO, Correto: True
# Progresso: 302/346
# Acurácia até agora: 83.11%
# Precisão até agora: 87.30%
# Recall até agora: 83.11%
# F1-score até agora: 83.66%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 303/346
# Acurácia até agora: 83.17%
# Precisão até agora: 87.35%
# Recall até agora: 83.17%
# F1-score até agora: 83.72%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 304/346
# Acurácia até agora: 83.22%
# Precisão até agora: 87.39%
# Recall até agora: 83.22%
# F1-score até agora: 83.77%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 305/346
# Acurácia até agora: 83.28%
# Precisão até agora: 87.43%
# Recall até agora: 83.28%
# F1-score até agora: 83.83%
#
# Real: EMBARGOS, Previsto: IMPUGNACAO, Correto: False
# Progresso: 306/346
# Acurácia até agora: 83.01%
# Precisão até agora: 87.11%
# Recall até agora: 83.01%
# F1-score até agora: 83.52%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 307/346
# Acurácia até agora: 83.06%
# Precisão até agora: 87.16%
# Recall até agora: 83.06%
# F1-score até agora: 83.58%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 308/346
# Acurácia até agora: 83.12%
# Precisão até agora: 87.20%
# Recall até agora: 83.12%
# F1-score até agora: 83.63%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 309/346
# Acurácia até agora: 83.17%
# Precisão até agora: 87.24%
# Recall até agora: 83.17%
# F1-score até agora: 83.68%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 310/346
# Acurácia até agora: 83.23%
# Precisão até agora: 87.28%
# Recall até agora: 83.23%
# F1-score até agora: 83.74%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 311/346
# Acurácia até agora: 82.96%
# Precisão até agora: 87.22%
# Recall até agora: 82.96%
# F1-score até agora: 83.58%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 312/346
# Acurácia até agora: 83.01%
# Precisão até agora: 87.26%
# Recall até agora: 83.01%
# F1-score até agora: 83.63%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 313/346
# Acurácia até agora: 83.07%
# Precisão até agora: 87.30%
# Recall até agora: 83.07%
# F1-score até agora: 83.68%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 314/346
# Acurácia até agora: 83.12%
# Precisão até agora: 87.34%
# Recall até agora: 83.12%
# F1-score até agora: 83.74%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 315/346
# Acurácia até agora: 83.17%
# Precisão até agora: 87.38%
# Recall até agora: 83.17%
# F1-score até agora: 83.79%
#
# Real: EMBARGOS, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 316/346
# Acurácia até agora: 82.91%
# Precisão até agora: 87.37%
# Recall até agora: 82.91%
# F1-score até agora: 83.62%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 317/346
# Acurácia até agora: 82.97%
# Precisão até agora: 87.41%
# Recall até agora: 82.97%
# F1-score até agora: 83.67%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 318/346
# Acurácia até agora: 83.02%
# Precisão até agora: 87.45%
# Recall até agora: 83.02%
# F1-score até agora: 83.73%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 319/346
# Acurácia até agora: 83.07%
# Precisão até agora: 87.49%
# Recall até agora: 83.07%
# F1-score até agora: 83.78%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 320/346
# Acurácia até agora: 83.12%
# Precisão até agora: 87.48%
# Recall até agora: 83.12%
# F1-score até agora: 83.81%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 321/346
# Acurácia até agora: 83.18%
# Precisão até agora: 87.53%
# Recall até agora: 83.18%
# F1-score até agora: 83.86%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 322/346
# Acurácia até agora: 83.23%
# Precisão até agora: 87.57%
# Recall até agora: 83.23%
# F1-score até agora: 83.91%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 323/346
# Acurácia até agora: 83.28%
# Precisão até agora: 87.61%
# Recall até agora: 83.28%
# F1-score até agora: 83.96%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 324/346
# Acurácia até agora: 83.33%
# Precisão até agora: 87.64%
# Recall até agora: 83.33%
# F1-score até agora: 84.01%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 325/346
# Acurácia até agora: 83.38%
# Precisão até agora: 87.68%
# Recall até agora: 83.38%
# F1-score até agora: 84.06%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 326/346
# Acurácia até agora: 83.44%
# Precisão até agora: 87.72%
# Recall até agora: 83.44%
# F1-score até agora: 84.11%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 327/346
# Acurácia até agora: 83.49%
# Precisão até agora: 87.76%
# Recall até agora: 83.49%
# F1-score até agora: 84.16%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 328/346
# Acurácia até agora: 83.54%
# Precisão até agora: 87.78%
# Recall até agora: 83.54%
# F1-score até agora: 84.20%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: UNIFICACAO-DE-PENAS, Correto: False
# Progresso: 329/346
# Acurácia até agora: 83.28%
# Precisão até agora: 87.35%
# Recall até agora: 83.28%
# F1-score até agora: 83.99%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 330/346
# Acurácia até agora: 83.33%
# Precisão até agora: 87.39%
# Recall até agora: 83.33%
# F1-score até agora: 84.04%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 331/346
# Acurácia até agora: 83.38%
# Precisão até agora: 87.43%
# Recall até agora: 83.38%
# F1-score até agora: 84.09%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 332/346
# Acurácia até agora: 83.43%
# Precisão até agora: 87.47%
# Recall até agora: 83.43%
# F1-score até agora: 84.13%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 333/346
# Acurácia até agora: 83.18%
# Precisão até agora: 87.41%
# Recall até agora: 83.18%
# F1-score até agora: 83.98%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 334/346
# Acurácia até agora: 83.23%
# Precisão até agora: 87.45%
# Recall até agora: 83.23%
# F1-score até agora: 84.03%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 335/346
# Acurácia até agora: 83.28%
# Precisão até agora: 87.48%
# Recall até agora: 83.28%
# F1-score até agora: 84.08%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 336/346
# Acurácia até agora: 83.33%
# Precisão até agora: 87.52%
# Recall até agora: 83.33%
# F1-score até agora: 84.12%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 337/346
# Acurácia até agora: 83.38%
# Precisão até agora: 87.56%
# Recall até agora: 83.38%
# F1-score até agora: 84.17%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 338/346
# Acurácia até agora: 83.43%
# Precisão até agora: 87.59%
# Recall até agora: 83.43%
# F1-score até agora: 84.22%
#
# Real: PROGRESSAO-DE-REGIME, Previsto: UNIFICACAO-DE-PENAS, Correto: False
# Progresso: 339/346
# Acurácia até agora: 83.19%
# Precisão até agora: 87.25%
# Recall até agora: 83.19%
# F1-score até agora: 83.98%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 340/346
# Acurácia até agora: 83.24%
# Precisão até agora: 87.24%
# Recall até agora: 83.24%
# F1-score até agora: 84.01%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 341/346
# Acurácia até agora: 82.99%
# Precisão até agora: 87.19%
# Recall até agora: 82.99%
# F1-score até agora: 83.87%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 342/346
# Acurácia até agora: 83.04%
# Precisão até agora: 87.24%
# Recall até agora: 83.04%
# F1-score até agora: 83.91%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 343/346
# Acurácia até agora: 83.09%
# Precisão até agora: 87.28%
# Recall até agora: 83.09%
# F1-score até agora: 83.96%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 344/346
# Acurácia até agora: 83.14%
# Precisão até agora: 87.31%
# Recall até agora: 83.14%
# F1-score até agora: 84.01%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 345/346
# Acurácia até agora: 83.19%
# Precisão até agora: 87.35%
# Recall até agora: 83.19%
# F1-score até agora: 84.06%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 346/346
# Acurácia até agora: 83.24%
# Precisão até agora: 87.39%
# Recall até agora: 83.24%
# F1-score até agora: 84.10%
#
# Acurácia final: 83.24%
# Precisão final: 87.39%
# Recall final: 83.24%
# F1-score final: 84.10%
#                                     precision    recall  f1-score   support
#
#                             AGRAVO       0.93      0.95      0.94        44
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO       1.00      1.00      1.00         1
#                           APELACAO       0.72      0.70      0.71        30
#           CONSIGNACAO-EM-PAGAMENTO       0.50      1.00      0.67         1
#            CONTRARRAZOES-AO-AGRAVO       0.08      1.00      0.15         1
#             CUMPRIMENTO-DE-SETENCA       0.83      0.33      0.48        15
#           DISSOLUCAO-DE-CONDOMINIO       1.00      0.67      0.80         3
#                           EMBARGOS       0.88      0.68      0.76        31
#       EXCECAO-DE-PRE-EXECUTIVIDADE       1.00      1.00      1.00         9
#           EXTINCAO-DE-PUNIBILIDADE       0.98      0.86      0.91        50
#                      HABEAS-CORPUS       1.00      1.00      1.00         3
#                         IMPUGNACAO       0.90      0.83      0.86        42
#                     INDENIZATORIAS       0.59      0.87      0.70        15
#                  INDULTO-COMUTACAO       0.88      0.82      0.85        17
#                 INTIMACAO-NEGATIVA       1.00      0.33      0.50         3
#             LIVRAMENTO-CONDICIONAL       0.91      0.91      0.91        22
#                            OFICIOS       0.94      1.00      0.97        15
#               PROGRESSAO-DE-REGIME       0.20      0.50      0.29         2
#                     REGISTRO-CIVIL       0.96      1.00      0.98        23
#                    REMICAO-DE-PENA       1.00      1.00      1.00         3
#                   SAIDA-TEMPORARIA       0.50      1.00      0.67         1
#          TRANSFERENCIA-DE-EXECUCAO       0.80      1.00      0.89         8
#                UNIFICACAO-DE-PENAS       0.33      0.33      0.33         3
#                          USUCAPIAO       0.67      1.00      0.80         4
#
#                           accuracy                           0.83       346
#                          macro avg       0.77      0.82      0.76       346
#                       weighted avg       0.87      0.83      0.84       346
#
# Relatório de classificação salvo em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classification_report_descricoes.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classification_report_descricoes.xlsx
# Resultados salvos em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classificacoes_descricoes.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Classificações/classificacoes_descricoes.xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Converter categorias para números
label_mapping = {label: idx for idx, label in enumerate(set(y_true + y_pred))}
numeric_labels_true = [label_mapping[label] for label in y_true]
numeric_labels_pred = [label_mapping[label] for label in y_pred]

df_comparison = pd.DataFrame({'Real': numeric_labels_true, 'Previsto': numeric_labels_pred})

# Calcular a acurácia
accuracy = (df_comparison['Real'] == df_comparison['Previsto']).mean()

# Calcular a média móvel para suavizar as curvas
df_comparison['Real_Smooth'] = df_comparison['Real'].rolling(window=10).mean()
df_comparison['Previsto_Smooth'] = df_comparison['Previsto'].rolling(window=10).mean()

# Criar o gráfico de linhas
plt.figure(figsize=(10, 5))  # Tamanho ajustado do gráfico
plt.plot(df_comparison.index, df_comparison['Real_Smooth'], label='Real', linestyle='-', color='blue')
plt.plot(df_comparison.index, df_comparison['Previsto_Smooth'], label='Previsto', linestyle='--', color='orange', alpha=0.7)
plt.xlabel('Índice (Posição na Sequência)', fontsize=12)  # Eixo X representando a posição na sequência
plt.ylabel('Classificação Média (Média Móvel)', fontsize=12)  # Eixo Y representando a média móvel das classificações
plt.title('Classificação Real e Prevista', fontsize=15)
plt.legend(loc='upper right', fontsize=10, frameon=False)  # Reduzir o tamanho da fonte da legenda e remover o quadro
plt.show()

# Exibir a acurácia
print(f'Acurácia Total: {accuracy:.2%}')
# Out:
# Acurácia Total: 83.24%

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar os rótulos de string para valores numéricos
label_encoder = LabelEncoder()
y_true_encoded = label_encoder.fit_transform(y_true)
y_pred_encoded = label_encoder.transform(y_pred)

# Verificar o mapeamento
label_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'AGRAVO': 0, 'ALVARA-JUDICIAL-LIBERACAO-DE-CORPO': 1, 'APELACAO': 2, 'CONSIGNACAO-EM-PAGAMENTO': 3, 'CONTRARRAZOES-AO-AGRAVO': 4, 'CUMPRIMENTO-DE-SETENCA': 5, 'DISSOLUCAO-DE-CONDOMINIO': 6, 'EMBARGOS': 7, 'EXCECAO-DE-PRE-EXECUTIVIDADE': 8, 'EXTINCAO-DE-PUNIBILIDADE': 9, 'HABEAS-CORPUS': 10, 'IMPUGNACAO': 11, 'INDENIZATORIAS': 12, 'INDULTO-COMUTACAO': 13, 'INTIMACAO-NEGATIVA': 14, 'LIVRAMENTO-CONDICIONAL': 15, 'OFICIOS': 16, 'PROGRESSAO-DE-REGIME': 17, 'REGISTRO-CIVIL': 18, 'REMICAO-DE-PENA': 19, 'SAIDA-TEMPORARIA': 20, 'TRANSFERENCIA-DE-EXECUCAO': 21, 'UNIFICACAO-DE-PENAS': 22, 'USUCAPIAO': 23}

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

# Binarizar os rótulos para o cálculo do AUC-ROC
y_true_binarized = label_binarize(y_true, classes=unique_labels)
y_pred_binarized = label_binarize(y_pred, classes=unique_labels)

# Calcular o AUC-ROC para cada classe
roc_auc_scores = {}
for i, label in enumerate(unique_labels):
    roc_auc_scores[label] = roc_auc_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-ROC
average_auc_roc = sum(roc_auc_scores.values()) / len(roc_auc_scores)

# Imprimir as pontuações AUC-ROC
print("Pontuações AUC-ROC por classe:")
for label, score in roc_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-ROC: {average_auc_roc:.2f}")
# Out:
# Pontuações AUC-ROC por classe:
# AGRAVO: 0.97
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 1.00
# APELACAO: 0.84
# CONSIGNACAO-EM-PAGAMENTO: 1.00
# CONTRARRAZOES-AO-AGRAVO: 0.98
# CUMPRIMENTO-DE-SETENCA: 0.67
# DISSOLUCAO-DE-CONDOMINIO: 0.83
# EMBARGOS: 0.83
# EXCECAO-DE-PRE-EXECUTIVIDADE: 1.00
# EXTINCAO-DE-PUNIBILIDADE: 0.93
# HABEAS-CORPUS: 1.00
# IMPUGNACAO: 0.91
# INDENIZATORIAS: 0.92
# INDULTO-COMUTACAO: 0.91
# INTIMACAO-NEGATIVA: 0.67
# LIVRAMENTO-CONDICIONAL: 0.95
# OFICIOS: 1.00
# PROGRESSAO-DE-REGIME: 0.74
# REGISTRO-CIVIL: 1.00
# REMICAO-DE-PENA: 1.00
# SAIDA-TEMPORARIA: 1.00
# TRANSFERENCIA-DE-EXECUCAO: 1.00
# UNIFICACAO-DE-PENAS: 0.66
# USUCAPIAO: 1.00
# Média AUC-ROC: 0.91

# %%
from sklearn.metrics import average_precision_score

# Calcular o AUC-PR para cada classe
pr_auc_scores = {}
for i, label in enumerate(unique_labels):
    pr_auc_scores[label] = average_precision_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-PR
average_auc_pr = sum(pr_auc_scores.values()) / len(pr_auc_scores)

# Imprimir as pontuações AUC-PR
print("Pontuações AUC-PR por classe:")
for label, score in pr_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-PR: {average_auc_pr:.2f}")
# Out:
# Pontuações AUC-PR por classe:
# AGRAVO: 0.90
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 1.00
# APELACAO: 0.53
# CONSIGNACAO-EM-PAGAMENTO: 0.50
# CONTRARRAZOES-AO-AGRAVO: 0.08
# CUMPRIMENTO-DE-SETENCA: 0.31
# DISSOLUCAO-DE-CONDOMINIO: 0.67
# EMBARGOS: 0.62
# EXCECAO-DE-PRE-EXECUTIVIDADE: 1.00
# EXTINCAO-DE-PUNIBILIDADE: 0.86
# HABEAS-CORPUS: 1.00
# IMPUGNACAO: 0.77
# INDENIZATORIAS: 0.52
# INDULTO-COMUTACAO: 0.73
# INTIMACAO-NEGATIVA: 0.34
# LIVRAMENTO-CONDICIONAL: 0.83
# OFICIOS: 0.94
# PROGRESSAO-DE-REGIME: 0.10
# REGISTRO-CIVIL: 0.96
# REMICAO-DE-PENA: 1.00
# SAIDA-TEMPORARIA: 0.50
# TRANSFERENCIA-DE-EXECUCAO: 0.80
# UNIFICACAO-DE-PENAS: 0.12
# USUCAPIAO: 0.67
# Média AUC-PR: 0.66

# %%
from sklearn.metrics import matthews_corrcoef

# Calcular MCC
mcc_value = matthews_corrcoef(y_true, y_pred)

# Print MCC
print(f"MCC: {mcc_value:.2f}")
# Out:
# MCC: 0.82

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Calcular o relatório de classificação
report_dict = classification_report(y_true, y_pred, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()

# Remover categorias com resultados zero e médias indesejadas
df_report = df_report[(df_report['precision'] > 0) | (df_report['recall'] > 0) | (df_report['f1-score'] > 0)]
df_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg', 'micro avg'], errors='ignore')

# Ajustar a largura das barras
bar_width = 0.6

# Ordenar os valores para visualização pela precisão
df_report_precision = df_report.sort_values(by='precision', ascending=False)

# Precisão
plt.figure(figsize=(12, 5))
df_report_precision['precision'].plot(kind='bar', color='skyblue', width=bar_width)
plt.title('Precisão por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Precisão', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo recall
df_report_recall = df_report.sort_values(by='recall', ascending=False)

# Recall
plt.figure(figsize=(12, 5))
df_report_recall['recall'].plot(kind='bar', color='lightgreen', width=bar_width)
plt.title('Recall por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Recall', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo f1-score
df_report_f1 = df_report.sort_values(by='f1-score', ascending=False)

# F1-Score
plt.figure(figsize=(12, 5))
df_report_f1['f1-score'].plot(kind='bar', color='salmon', width=bar_width)
plt.title('F1-Score por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Mapeamento das categorias para inglês
category_mapping = {
    "INTIMACAO-NEGATIVA": "NEGATIVE_INTIMATION",
    "AGRAVO": "APPEAL",
    "REGISTRO-CIVIL": "CIVIL_REGISTRATION",
    "INDENIZATORIAS": "INDEMNIFICATIONS",
    "IMPUGNACAO": "CONTESTATION",
    "EMBARGOS": "EMBARGOES",
    "EXTINCAO-DE-PUNIBILIDADE": "EXTINCTION_OF_PUNISHABILITY",
    "OFICIOS": "OFFICES",
    "LIVRAMENTO-CONDICIONAL": "CONDITIONAL_RELEASE",
    "APELACAO": "APPEAL",
    "DISSOLUCAO-DE-CONDOMINIO": "DISSOLUTION_OF_CONDOMINIUM",
    "CUMPRIMENTO-DE-SETENCA": "SENTENCE_COMPLIANCE",
    "HABEAS-CORPUS": "HABEAS_CORPUS",
    "REMICAO-DE-PENA": "SENTENCE_REDUCTION",
    "UNIFICACAO-DE-PENAS": "PENALTY_UNIFICATION",
    "INDULTO-COMUTACAO": "PARDON_COMMUTATION",
    "PROGRESSAO-DE-REGIME": "REGIME_PROGRESS",
    "EXCECAO-DE-PRE-EXECUTIVIDADE": "PRE_EXECUTION_EXCEPTION",
    "TRANSFERENCIA-DE-EXECUCAO": "EXECUTION_TRANSFER",
    "USUCAPIAO": "ADVERSE_POSSESSION",
    "SAIDA-TEMPORARIA": "TEMPORARY_EXIT",
    "ALVARA-JUDICIAL-LIBERACAO-DE-CORPO": "JUDICIAL_RELEASE_ORDER",
    "CONSIGNACAO-EM-PAGAMENTO": "PAYMENT_CONSIGNATION",
    "CONTRARRAZOES-AO-AGRAVO": "APPEAL_RESPONSES"
}

# Calcular o relatório de classificação
report_dict = classification_report(y_true, y_pred, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()

# Remover categorias com resultados zero e médias indesejadas
df_report = df_report[(df_report['precision'] > 0) | (df_report['recall'] > 0) | (df_report['f1-score'] > 0)]
df_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg', 'micro avg'], errors='ignore')

# Ajustar a largura das barras
bar_width = 0.6

# Substituir os nomes das categorias pelas suas versões em inglês
df_report.index = [category_mapping.get(category, category) for category in df_report.index]

# Ordenar os valores para visualização pela precisão
df_report_precision = df_report.sort_values(by='precision', ascending=False)

# Precisão
plt.figure(figsize=(12, 5))
df_report_precision['precision'].plot(kind='bar', color='skyblue', width=bar_width)
plt.title('Precision by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo recall
df_report_recall = df_report.sort_values(by='recall', ascending=False)

# Recall
plt.figure(figsize=(12, 5))
df_report_recall['recall'].plot(kind='bar', color='lightgreen', width=bar_width)
plt.title('Recall by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Recall', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo f1-score
df_report_f1 = df_report.sort_values(by='f1-score', ascending=False)

# F1-Score
plt.figure(figsize=(12, 5))
df_report_f1['f1-score'].plot(kind='bar', color='salmon', width=bar_width)
plt.title('F1-Score by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

df_sample = pd.DataFrame({
    'issue_area': y_true,
    'resultados': y_pred
})

# Calcular a matriz de confusão
cm = confusion_matrix(df_sample['issue_area'], df_sample['resultados'], labels=df_sample['issue_area'].unique())

# Normalizar a matriz de confusão
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Criar rótulos numéricos para as categorias
categories = [f'Categoria {i+1}' for i in range(len(df_sample['issue_area'].unique()))]

# Criar DataFrames para as matrizes de confusão
df_cm = pd.DataFrame(cm, index=categories, columns=categories)
df_cm_normalized = pd.DataFrame(cm_normalized, index=categories, columns=categories)

# Definir o diretório de saída
output_dir = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Descrições/Matriz-confusão'

# Salvar as matrizes de confusão em CSV e Excel
df_cm.to_csv(f'{output_dir}/matriz_de_confusao.csv', index=True)
df_cm_normalized.to_csv(f'{output_dir}/matriz_de_confusao_normalizada.csv', index=True)

df_cm.to_excel(f'{output_dir}/matriz_de_confusao.xlsx', index=True)
df_cm_normalized.to_excel(f'{output_dir}/matriz_de_confusao_normalizada.xlsx', index=True)

# Plotar a matriz de confusão normal
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Rótulo previsto', fontsize=14)
plt.ylabel('Rótulo verdadeiro', fontsize=14)
plt.title('Matriz de Confusão - Conjunto de Teste', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# Plotar a matriz de confusão normalizada
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Rótulo previsto', fontsize=14)
plt.ylabel('Rótulo verdadeiro', fontsize=14)
plt.title('Matriz de Confusão Normalizada - Conjunto de Teste', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()
