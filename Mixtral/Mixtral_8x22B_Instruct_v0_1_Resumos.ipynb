# %% [markdown]
# <a href="https://colab.research.google.com/github/Willgnner-Santos/LLM_PortugueseLegalDocClassifier/blob/main/Mixtral/Mixtral_8x22B_Instruct_v0_1_Resumos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install tiktoken langchain-community langchainhub langchain_openai langchain
# !!pip install imbalanced-learn

from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

api_key = ''

llm = ChatOpenAI(
                api_key= api_key,
                base_url="https://api.together.xyz/v1",
                model='mistralai/Mixtral-8x22B-Instruct-v0.1',
                max_tokens=100,
                temperature=0.1,
                verbose=True
                )

def get_label(result):
    return result.content
# Out:
# Mounted at /content/drive
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.1 MB/s eta 0:00:00
# Collecting langchain-community
#   Downloading langchain_community-0.2.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 48.3 MB/s eta 0:00:00
# Collecting langchainhub
#   Downloading langchainhub-0.1.20-py3-none-any.whl (5.0 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-0.1.17-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 5.9 MB/s eta 0:00:00
# Collecting langchain
#   Downloading langchain-0.2.9-py3-none-any.whl (987 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 987.7/987.7 kB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting langchain-core<0.3.0,>=0.2.12 (from langchain-community)
#   Downloading langchain_core-0.2.21-py3-none-any.whl (372 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.0/372.0 kB 37.1 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-community)
#   Downloading langsmith-0.1.92-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.0/135.0 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.25.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (24.1)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.32.0.20240712-py3-none-any.whl (15 kB)
# Collecting openai<2.0.0,>=1.32.0 (from langchain_openai)
#   Downloading openai-1.35.15-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.6/328.6 kB 34.2 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.12->langchain-community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain-community)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (4.12.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain_openai) (1.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain-community)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: types-requests, orjson, mypy-extensions, marshmallow, jsonpointer, h11, typing-inspect, tiktoken, langchainhub, jsonpatch, httpcore, langsmith, httpx, dataclasses-json, openai, langchain-core, langchain-text-splitters, langchain_openai, langchain, langchain-community
# Successfully installed dataclasses-json-0.6.7 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.9 langchain-community-0.2.7 langchain-core-0.2.21 langchain-text-splitters-0.2.2 langchain_openai-0.1.17 langchainhub-0.1.20 langsmith-0.1.92 marshmallow-3.21.3 mypy-extensions-1.0.0 openai-1.35.15 orjson-3.10.6 tiktoken-0.7.0 types-requests-2.32.0.20240712 typing-inspect-0.9.0

# %%
PROMPT_CLASSIFICACAO = (
    "Classifique as petições processuais abaixo em uma das seguintes categorias: "
    "AGRAVO, CONTRARRAZOES-AO-AGRAVO, EMBARGOS, EXTINCAO-DE-PUNIBILIDADE, "
    "HABEAS-CORPUS, IMPUGNACAO, INDULTO-COMUTACAO, INTIMACAO-NEGATIVA, "
    "LIVRAMENTO-CONDICIONAL, OFICIOS, PROGRESSAO-DE-REGIME, REMICAO-DE-PENA, "
    "TRANSFERENCIA-DE-EXECUCAO, UNIFICACAO-DE-PENAS, APELACAO, REGISTRO-CIVIL, "
    "CUMPRIMENTO-DE-SETENCA, INDENIZATORIAS, EXCECAO-DE-PRE-EXECUTIVIDADE, "
    "DISSOLUCAO-DE-CONDOMINIO, CONSIGNACAO-EM-PAGAMENTO, ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, "
    "SAIDA-TEMPORARIA, USUCAPIAO. "
    "Retorne apenas a categoria e nada mais. "
    "Texto: {texto} "
    "Categoria:"
)

PROMPT_RESUMO = (
    "Faça um resumo explicativo de 200 palavras da petição abaixo, o resumo deve descrever sobre o que o texto fala de modo geral, "
    "ignorando pessoas, números, locais, ou especificidades que não definem a ideia da petição, permitindo a classificação da petição "
    "entre as seguintes classes: AGRAVO, CONTRARRAZOES-AO-AGRAVO, EMBARGOS, EXTINCAO-DE-PUNIBILIDADE, "
    "HABEAS-CORPUS, IMPUGNACAO, INDULTO-COMUTACAO, INTIMACAO-NEGATIVA, "
    "LIVRAMENTO-CONDICIONAL, OFICIOS, PROGRESSAO-DE-REGIME, REMICAO-DE-PENA, "
    "TRANSFERENCIA-DE-EXECUCAO, UNIFICACAO-DE-PENAS, APELACAO, REGISTRO-CIVIL, "
    "CUMPRIMENTO-DE-SETENCA, INDENIZATORIAS, EXCECAO-DE-PRE-EXECUTIVIDADE, "
    "DISSOLUCAO-DE-CONDOMINIO, CONSIGNACAO-EM-PAGAMENTO, ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, "
    "SAIDA-TEMPORARIA, USUCAPIAO. "
    "Retorne apenas o resumo explicativo e nada mais. "
    "---------------------- "
    "Petição de {classe}: {texto}"
    "Resumo Explicativo:"
)

PROMPT_DESCRICAO = (
    "Classifique a petição processual nas seguintes categorias: "
    "- AGRAVO: Petições que contestam decisões judiciais, solicitando a revisão dessas decisões, geralmente por inconformidade com a decisão proferida em primeira instância. "
    "- CONTRARRAZOES-AO-AGRAVO: Petições que apresentam argumentos contrários a um agravo interposto, defendendo a manutenção da decisão judicial atacada e refutando os pontos levantados pelo agravante. "
    "- EMBARGOS: Petições que visam esclarecer ou corrigir omissões, contradições ou obscuridades em decisões judiciais, buscando a perfeita compreensão e aplicação da decisão. "
    "- EXTINCAO-DE-PUNIBILIDADE: Petições que tratam da extinção da punibilidade de uma pena por razões como prescrição, anistia, perdão judicial ou cumprimento integral da pena imposta. "
    "- HABEAS-CORPUS: Petições que visam garantir a liberdade de um indivíduo, alegando prisão ilegal ou abuso de poder, e buscando a concessão do benefício de soltura imediata. "
    "- IMPUGNACAO: Petições que questionam a precisão de relatórios ou decisões processuais, solicitando correções específicas para assegurar a justiça e a veracidade dos documentos processuais. "
    "- INDULTO-COMUTACAO: Petições que solicitam a comutação ou redução de pena com base em decretos presidenciais, leis específicas ou outros fundamentos legais que justifiquem o benefício. "
    "- INTIMACAO-NEGATIVA: Petições que tratam da intimação do sentenciado que não foi localizado, solicitando nova tentativa de intimação ou a adoção de outras medidas para assegurar a comunicação processual. "
    "- LIVRAMENTO-CONDICIONAL: Petições que solicitam a concessão de livramento condicional, alegando que o apenado cumpriu os requisitos legais, como bom comportamento e cumprimento de parte da pena. "
    "- OFICIOS: Solicitações formais de providências ou informações sobre o andamento de processos penais, destacando a importância da celeridade e da razoável duração do processo para a garantia dos direitos dos envolvidos. "
    "- PROGRESSAO-DE-REGIME: Petições que solicitam a progressão de regime prisional para um apenado, alegando que este cumpriu os requisitos legais, como o cumprimento de parte da pena e bom comportamento. "
    "- REMICAO-DE-PENA: Petições que solicitam a remição de pena por estudo ou trabalho realizado durante o cumprimento da pena, destacando o esforço do apenado em se reintegrar à sociedade. "
    "- TRANSFERENCIA-DE-EXECUCAO: Petições que solicitam a transferência da execução da pena para uma comarca mais próxima da residência do apenado, visando facilitar o acompanhamento familiar e a reintegração social. "
    "- UNIFICAO-DE-PENAS: Petições que tratam da unificação de penas decorrentes de diferentes processos, visando a fixação de um regime de cumprimento único e adequado à situação do apenado. "
    "- APELACAO: Petições que solicitam a reavaliação de uma decisão judicial em instância superior. "
    "- REGISTRO-CIVIL: Petições relacionadas ao registro de nascimentos, casamentos, óbitos e outros atos civis. "
    "- CUMPRIMENTO-DE-SETENCA: Petições que solicitam a execução de uma decisão judicial já transitada em julgado. "
    "- INDENIZATORIAS: Petições que solicitam compensação financeira por danos sofridos. "
    "- EXCECAO-DE-PRE-EXECUTIVIDADE: Petições que buscam a extinção de um processo executivo antes da sua efetiva execução, geralmente por questões de ordem pública. "
    "- DISSOLUCAO-DE-CONDOMINIO: Petições que solicitam a dissolução de um condomínio e a partilha de seus bens. "
    "- CONSIGNACAO-EM-PAGAMENTO: Petições que buscam depositar judicialmente um valor devido, quando o credor se recusa a receber o pagamento diretamente. "
    "- ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: Petições que solicitam a liberação de um corpo para sepultamento. "
    "- SAIDA-TEMPORARIA: Petições que solicitam a autorização para que o apenado saia temporariamente da prisão por razões específicas, como visita à família. "
    "- USUCAPIAO: Petições que buscam o reconhecimento da aquisição da propriedade de um bem por meio de sua posse prolongada e contínua. "
    "--------------------- "
    "Retorne apenas a classe e nada mais. "
    "Petição: {texto} "
    "Classe:"
)

# %%
import pandas as pd

# Carregar o dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/test_data.csv')

import tiktoken
import matplotlib.pyplot as plt

enc = tiktoken.get_encoding("cl100k_base")

# Função para contar tokens
def count_tokens(text):
    return len(enc.encode(text))

# Adicionar coluna com a contagem de tokens
df['token_count'] = df['facts'].apply(count_tokens)

# Exibir o número total de textos no dataset original
total_texts = len(df)
print(f'Total de textos no dataset original: {total_texts}')

# Filtrar textos com menos de 60000 tokens
filtered_df = df[df['token_count'] < 60000].drop(columns=['token_count'])

# Exibir o número de textos filtrados no terminal
total_filtered_texts = len(filtered_df)
print(f'Total de textos filtrados com menos de 60000 tokens: {total_filtered_texts}')
# Out:
# Total de textos no dataset original: 346
# Total de textos filtrados com menos de 60000 tokens: 346

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calcular média e mediana
mean_value = df['token_count'].mean()
median_value = df['token_count'].median()

# Plotar histograma da quantidade de tokens
plt.figure(figsize=(6, 4))
plt.hist(df['token_count'], bins=30, edgecolor='black')
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Média: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {median_value:.2f}')
plt.xlabel('Número de Tokens', fontsize=12)
plt.ylabel('Frequência', fontsize=12)
plt.title('Histograma da Quantidade de Tokens', fontsize=15)
plt.legend()
plt.show()

# %%
import pandas as pd

# Carregar o dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/test_data.csv')

# Selecionar um exemplo de cada categoria de 1 a 24
unique_labels = range(1, 25)
examples = []

for label in unique_labels:
    example = df[df['issue_area_label'] == label].head(1)
    examples.append(example)

# Concatenar todos os exemplos em um único DataFrame
examples_df = pd.concat(examples)

# Selecionar as colunas de interesse
selected_columns = examples_df[['issue_area', 'issue_area_label']]

# Exibir o dataset com as colunas selecionadas
from IPython.display import display

display(selected_columns)

print(selected_columns)
# Out:
#                              issue_area  issue_area_label
# 1                                AGRAVO                 1
# 104  ALVARA-JUDICIAL-LIBERACAO-DE-CORPO                 2
# 10                             APELACAO                 3
# 125            CONSIGNACAO-EM-PAGAMENTO                 4
# 224             CONTRARRAZOES-AO-AGRAVO                 5
# 18               CUMPRIMENTO-DE-SETENCA                 6
# 11             DISSOLUCAO-DE-CONDOMINIO                 7
# 6                              EMBARGOS                 8
# 59         EXCECAO-DE-PRE-EXECUTIVIDADE                 9
# 7              EXTINCAO-DE-PUNIBILIDADE                10
# 19                        HABEAS-CORPUS                11
# 5                            IMPUGNACAO                12
# 4                        INDENIZATORIAS                13
# 34                    INDULTO-COMUTACAO                14
# 0                    INTIMACAO-NEGATIVA                15
# 9                LIVRAMENTO-CONDICIONAL                16
# 8                               OFICIOS                17
# 43                 PROGRESSAO-DE-REGIME                18
# 2                        REGISTRO-CIVIL                19
# 22                      REMICAO-DE-PENA                20
# 88                     SAIDA-TEMPORARIA                21
# 62            TRANSFERENCIA-DE-EXECUCAO                22
# 26                  UNIFICACAO-DE-PENAS                23
# 65                            USUCAPIAO                24
#                              issue_area  issue_area_label
# 1                                AGRAVO                 1
# 104  ALVARA-JUDICIAL-LIBERACAO-DE-CORPO                 2
# 10                             APELACAO                 3
# 125            CONSIGNACAO-EM-PAGAMENTO                 4
# 224             CONTRARRAZOES-AO-AGRAVO                 5
# 18               CUMPRIMENTO-DE-SETENCA                 6
# 11             DISSOLUCAO-DE-CONDOMINIO                 7
# 6                              EMBARGOS                 8
# 59         EXCECAO-DE-PRE-EXECUTIVIDADE                 9
# 7              EXTINCAO-DE-PUNIBILIDADE                10
# 19                        HABEAS-CORPUS                11
# 5                            IMPUGNACAO                12
# 4                        INDENIZATORIAS                13
# 34                    INDULTO-COMUTACAO                14
# 0                    INTIMACAO-NEGATIVA                15
# 9                LIVRAMENTO-CONDICIONAL                16
# 8                               OFICIOS                17
# 43                 PROGRESSAO-DE-REGIME                18
# 2                        REGISTRO-CIVIL                19
# 22                      REMICAO-DE-PENA                20
# 88                     SAIDA-TEMPORARIA                21
# 62            TRANSFERENCIA-DE-EXECUCAO                22
# 26                  UNIFICACAO-DE-PENAS                23
# 65                            USUCAPIAO                24

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_distances
import numpy as np
import pandas as pd

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(filtered_df['facts'])

labels = filtered_df['issue_area'].unique()
centroids = []

for label in labels:
    indices = filtered_df['issue_area'] == label
    cluster_vectors = X[indices]
    cluster_texts = filtered_df['facts'][indices]

    centroid_vector = cluster_vectors.mean(axis=0)
    centroid_vector = np.asarray(centroid_vector).flatten()

    distances = cosine_distances(cluster_vectors, centroid_vector.reshape(1, -1))
    closest_index = np.argmin(distances)
    centroid_text = cluster_texts.iloc[closest_index]

    centroids.append({'issue_area': label, 'centroid_text': centroid_text})

# Criar DataFrame com os centróides
centroids_df = pd.DataFrame(centroids)

# Exibir as centróides no terminal
print("Centróides:")
print(centroids_df)

# Salvar os resultados em arquivos CSV e Excel
csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Texto-centroids/centroids.csv'
excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Texto-centroids/centroids.xlsx'

centroids_df.to_csv(csv_path, index=False)
centroids_df.to_excel(excel_path, index=False)

print(f"Results saved to {csv_path} and {excel_path}")
# Out:
# Centróides:
#                             issue_area  \
# 0                   INTIMACAO-NEGATIVA
# 1                               AGRAVO
# 2                       REGISTRO-CIVIL
# 3                       INDENIZATORIAS
# 4                           IMPUGNACAO
# 5                             EMBARGOS
# 6             EXTINCAO-DE-PUNIBILIDADE
# 7                              OFICIOS
# 8               LIVRAMENTO-CONDICIONAL
# 9                             APELACAO
# 10            DISSOLUCAO-DE-CONDOMINIO
# 11              CUMPRIMENTO-DE-SETENCA
# 12                       HABEAS-CORPUS
# 13                     REMICAO-DE-PENA
# 14                 UNIFICACAO-DE-PENAS
# 15                   INDULTO-COMUTACAO
# 16                PROGRESSAO-DE-REGIME
# 17        EXCECAO-DE-PRE-EXECUTIVIDADE
# 18           TRANSFERENCIA-DE-EXECUCAO
# 19                           USUCAPIAO
# 20                    SAIDA-TEMPORARIA
# 21  ALVARA-JUDICIAL-LIBERACAO-DE-CORPO
# 22            CONSIGNACAO-EM-PAGAMENTO
# 23             CONTRARRAZOES-AO-AGRAVO
#
#                                         centroid_text
# 0   ao juízo da vara de execução de pena e medidas...
# 1   ao juízo da vara de execução de penas e medida...
# 2   juizo direito vara fazenda publica municipal r...
# 3   juizo civel comarca goiania go jose lope silva...
# 4   excelentissimo senhor doutor juiz direito vara...
# 5   excelentissimo senhor doutor juiz direito vara...
# 6   ao juízo da 3ª vara de execução penal da comar...
# 7   ofício nep n 682020 goiânia 03 de junho de 202...
# 8   ao juízo da 3ª vara de execução penal da comar...
# 9   excelentissimo senhor doutor juiz direito vara...
# 10  juizo vara civel comarca goiania go silvio jos...
# 11  excelentissimo senhor doutor juiz direito vara...
# 12  excelentíssimo senhor doutor desembargador pre...
# 13  ao juízo da 3ª vara de execução penal da comar...
# 14  ao juízo da 3ª vara de execução penal da comar...
# 15  ao juízo da vara de execução de penas e medida...
# 16  ao juízo da 3ª vara de execução penal da comar...
# 17  excelentissimo senhor doutor juiz direito vara...
# 18  ao juízo da 3ª vara de execução de penal da co...
# 19  juizo direito vara civel comarca goiania goias...
# 20  ao juízo da 3ª vara de execução penal da comar...
# 21  juizo plantonista comarca goiania go joao marc...
# 22  juizo vara civel comarca goiania goias viniciu...
# 23  ao juízo da vara de execução de penas e medida...
# Results saved to /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Texto-centroids/centroids.csv and /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Texto-centroids/centroids.xlsx

# %%
prompt_template_resumo = PromptTemplate(
    input_variables=["texto","classe"],
    template=PROMPT_RESUMO,
)

chain_resumo = prompt_template_resumo | llm | get_label

resumos = []

for label, centroid in zip(labels, centroids):
    resumo = chain_resumo.invoke({'texto': centroid['centroid_text'], 'classe': label})
    resumos.append(resumo)
    print(f"\nResumo para {label}:\n{resumo}\n")
# Out:
# Resumo para INTIMACAO-NEGATIVA:
#  A petição trata de uma Intimação Negativa, onde a Defensoria Pública do Estado de Goiás solicita ao Juízo da Vara de Execução de Pena e Medidas Alternativas da Comarca de Goiânia que o apenado compareça a uma audiência admonitória. A Defensoria Pública está defendendo os direitos do sentençado, cujo nome foi anon
#
#
# Resumo para AGRAVO:
#  A petição trata de um agravo interposto pela defensoria pública em nome de um indivíduo que cumpriu integralmente sua pena privativa de liberdade, mas ainda não pagou a multa criminal imposta. A defensoria argumenta que a decisão que indeferiu o pedido de declaração de extinção de punibilidade pelo integral cumprimento das sanções impostas é
#
#
# Resumo para REGISTRO-CIVIL:
#  A petição trata de uma solicitação de REGISTRO-CIVIL para a retificação de um registro civil. O requerente, que se encontra em situação de hipossuficiência econômica, solicita a concessão de gratuidade da justiça para arcar com os custos processuais e honorários advocatícios. O requerente argumenta que, de ac
#
#
# Resumo para INDENIZATORIAS:
#  A petição trata de uma ação de indenização por danos materiais e morais, apresentada por um requerente que foi vítima de uma fraude por parte de dois advogados. O requerente contratou o primeiro advogado para atuar em um processo de indenização civil, mas o advogado não repassou todo o valor recebido pelo requerente, alegando
#
#
# Resumo para IMPUGNACAO:
#  A petição trata de uma ação de impugnação, onde o requerente, assistido pela Defensoria Pública do Estado de Goiás, questiona o cumprimento de uma sentença relacionada ao pagamento de taxas condominiais. O requerente argumenta que houve uma violação do devido processo legal, uma vez que não houve a devida intimidade pessoal dos executados durante
#
#
# Resumo para EMBARGOS:
#  A petição trata de um pedido de Embargos, onde o defensor público, atuando como curador especial, solicita ao juiz que observe as prerrogativas dos membros da defensoria pública, especialmente em relação ao prazo dobrado de intimar pessoalmente o réu. O defensor argumenta que a jurisprudência superior admite a citação edital na ação monitorial
#
#
# Resumo para EXTINCAO-DE-PUNIBILIDADE:
#  A petição trata de uma solicitação de extinção de punibilidade para um indivíduo condenado por dois crimes, um deles envolvendo o uso de uma arma branca. O réu foi condenado a uma pena unificada de 5 anos e 6 meses de reclusão, mas devido a uma mudança na legislação, a pena pelo uso de arma br
#
#
# Resumo para OFICIOS:
#  A petição trata de um ofício solicitando informações sobre a manutenção da prisão de um indivíduo, cujo nome foi anonimizado. O indivíduo foi originalmente preso preventivamente em fevereiro de 2019, mas foi libertado em setembro de 2019 por meio de um alvará de soltura. No entanto, devido a
#
#
# Resumo para LIVRAMENTO-CONDICIONAL:
#  A petição trata de uma solicitação de livramento condicional para um indivíduo que está cumprindo uma pena privativa de liberdade. O indivíduo está em tratamento médico neurológico e tem diagnóstico de disfunção executiva, transtorno cognitivo e de personalidade pós-traumático. O texto argumenta que o direito à saúde é
#
#
# Resumo para APELACAO:
#  A petição trata de uma apelação interposta pela Defensoria Pública do Estado de Goiás em nome da apelante Rita Vanessa Alves Bandiera contra a decisão do juiz que extinguiu o processo. A defesa argumenta que houve uma violação ao direito de defesa, uma vez que a Defensoria Pública não foi devidamente intimada, o que resultou na ausência de manifest
#
#
# Resumo para DISSOLUCAO-DE-CONDOMINIO:
#  A petição trata de uma ação de DISSOLUÇÃO-DE-CONDOMÍNIO, onde o requerente busca a extinção do condomínio existente sobre um imóvel adquirido durante o casamento, que não foi devidamente partilhado após o divórcio. O requerente argumenta que a indivisão temporária do bem imóvel devido ao caráter
#
#
# Resumo para CUMPRIMENTO-DE-SETENCA:
#  A petição trata de uma solicitação de Cumprimento de Sentença, onde o Banco do Brasil está buscando o pagamento de uma dívida de um indivíduo chamado Thiago Fernando Martins. A Defensoria Pública do Estado de Goiás está representando o executado. A petição destaca a necessidade de observância das prerrogativas dos membros da Defensoria
#
#
# Resumo para HABEAS-CORPUS:
#  A petição é um pedido de habeas corpus para beneficiar o paciente Ubes Eropeu de Oliveira, que está atualmente detido na Casa de Prisão Provisória do Complexo Prisional de Aparecida de Goiânia. O paciente foi condenado a uma pena de 02 anos e 06 meses de reclusão em regime inicial semiaberto por
#
#
# Resumo para REMICAO-DE-PENA:
#  A petição trata de uma solicitação de remição de pena para um indivíduo que está cumprindo uma pena privativa de liberdade em regime aberto, com monitoração eletrônica. O indivíduo tem uma condição de saúde vulnerável, sendo portador do vírus HIV, e enfrenta dificuldades para cumprir as restrições impostas pela monitoração
#
#
# Resumo para UNIFICACAO-DE-PENAS:
#  A petição trata de uma solicitação de unificação de penas para um indivíduo que foi condenado a uma pena privativa de liberdade de quatro anos em regime inicial aberto por infração ao artigo 157 do Código Penal. O indivíduo foi incluído no regime aberto domiciliar com monitoração eletrônica, mas foi registrada uma sup
#
#
# Resumo para INDULTO-COMUTACAO:
#  A petição trata de um pedido de indulto e comutação de pena para um indivíduo que foi condenado a três anos de reclusão por infração ao artigo 16 da Lei 10.826/03 e quatro meses de prestação de serviços à comunidade pela sanção prevista no artigo 28 da Lei 11.3
#
#
# Resumo para PROGRESSAO-DE-REGIME:
#  A petição solicita uma progressão de regime para um indivíduo que está cumprindo uma pena de prisão. O requerente, através de um defensor público, argumenta que o indivíduo já adimpliu o requisito temporal para a concessão do regime semiaberto há quase um ano. Portanto, a petição pede a unificação das penas e a fixação
#
#
# Resumo para EXCECAO-DE-PRE-EXECUTIVIDADE:
#  A petição trata de uma exceção de pré-executividade, um recurso excepcional que permite ao executado defender seus direitos e interesses, independentemente do prazo de oferecimento. O requerente argumenta que a citacão inicial é nula, uma vez que não foram adotadas medidas para realização da citacão pessoal e a citacão ficta não se aplica n
#
#
# Resumo para TRANSFERENCIA-DE-EXECUCAO:
#  A petição solicita a transferência da execução de uma pena para uma comarca diferente, onde o condenado reside. O condenado está atualmente cumprindo a pena em regime aberto domiciliar com monitoração eletrônica. A principal justificativa para a transferência é a reintegração social do condenado, que seria facilitada pelo fato de cumprir a pena na cidade
#
#
# Resumo para USUCAPIAO:
#  A petição trata de uma ação de usucapião, que é um processo legal pelo qual uma pessoa pode adquirir a propriedade de um imóvel por meio da posse contínua e ininterrupta por um período determinado de tempo. Os requerentes, Adalberto e Ana Maria, afirmam ter adquirido o imóvel por meio da usucapião, tendo exercido
#
#
# Resumo para SAIDA-TEMPORARIA:
#  A petição trata de uma solicitação de saída temporária para um indivíduo que está cumprindo uma pena em regime aberto domiciliar com monitoração eletrônica. O indivíduo já recebeu autorização para saída temporária anteriormente e agora está solicitando uma nova saída temporária para visitar sua família na cidade de Ipameri, Go
#
#
# Resumo para ALVARA-JUDICIAL-LIBERACAO-DE-CORPO:
#  A petição solicita um alvará judicial para a liberação do corpo de uma pessoa falecida, com o objetivo de realizar o traslado e sepultamento. O requerente é filho da falecida e afirma que não possui recursos suficientes para arcar com os custos processuais e honorários advocatícios. Ele também destaca a necessidade de observância
#
#
# Resumo para CONSIGNACAO-EM-PAGAMENTO:
#  A petição trata de CONSIGNACAO-EM-PAGAMENTO, onde o requerente solicita a concessão de gratuidade da justiça e a autorização para depositar a quantia devida em juízo. O requerente alega insuficiência de recursos financeiros e apresenta documentação para comprovar sua hipossuficiência. A petição também argumenta que o cred
#
#
# Resumo para CONTRARRAZOES-AO-AGRAVO:
#  A petição trata de uma resposta à apelação interposta pelo Ministério Público contra a decisão de um juízo que decretou a extinção da punibilidade do agravado por ocorrência da prescrição executória. A defesa argumenta que o prazo de prescrição executória começa a contar a partir do dia em que a sentença condenatória transita em jul

# %%
# Classifica os textos diretamente usando o PROMPT_CLASSIFICACAO, usando textos resumos

import re
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import unicodedata

# Função para normalizar texto
def normalize_text(text):
    """
    Normaliza o texto para comparação.
    Converte para minúsculas e remove espaços extras.
    """
    text = text.lower()  # Converte para minúsculas
    text = re.sub(r'\s+', ' ', text).strip()  # Remove espaços extras
    return text

# Função para remover acentos
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return "".join([c for c in nfkd_form if not unicodedata.combining(c)])

# Função para limpar e normalizar a categoria
def clean_category(category):
    category = re.sub(r'[^a-zA-Z0-9\-]', '', category)  # Remove caracteres especiais
    category = re.sub(r'\s+', '-', category).strip()  # Substitui espaços por traços e remove espaços extras
    return category.upper()  # Converte para maiúsculas

# Função para encontrar a melhor correspondência
def get_best_match(result, valid_labels):
    result = clean_category(result)  # Limpar e normalizar a categoria
    result = remove_accents(result).strip().upper()

    best_match = None
    best_score = -1

    for label in valid_labels:
        cleaned_label = clean_category(remove_accents(label.strip().upper()))
        if result == cleaned_label:
            return label  # Retorna a correspondência exata imediatamente
        score = len(set(result) & set(cleaned_label)) / len(set(result) | set(cleaned_label))  # Semelhança de Jaccard
        if score > best_score:
            best_score = score
            best_match = label

    return best_match

# Inicializar variáveis para rastreamento das métricas
y_true = []
y_pred = []

# Variáveis para rastrear a acurácia
correct_count = 0
total_count = 0

# Lista para armazenar os resultados
results = []

# Lista de rótulos válidos
valid_labels = filtered_df['issue_area'].unique().tolist()

# Preparar o modelo para classificação com resumos
prompt_template_classificacao = PromptTemplate(
    input_variables=["texto"],
    template=PROMPT_CLASSIFICACAO,
)

chain_classificacao = prompt_template_classificacao | llm | get_label

resumos_df = pd.DataFrame({
    'issue_area': labels,
    'resumo_text': resumos
})

# Classificação usando resumos
for index, row in filtered_df.iterrows():
    resumo_text = resumos_df[resumos_df['issue_area'] == row['issue_area']]['resumo_text'].values[0]
    prompt_with_classificacao = prompt_template_classificacao.format(texto=resumo_text)
    result = chain_classificacao.invoke({'texto': resumo_text}).strip()  # Remover espaços em branco extras

    # Normalizar textos para comparação e remover acentos
    normalized_label = clean_category(remove_accents(row['issue_area'].strip().upper()))
    normalized_result = get_best_match(result, valid_labels)  # Garantir que a saída seja uma das classes válidas

    # Verificar se a previsão é correta
    is_correct = normalized_label == clean_category(remove_accents(normalized_result.strip().upper()))

    # Imprimir o resultado retornado e a etiqueta esperada para depuração
    print(f'Real: {row["issue_area"]}, Previsto: {normalized_result}, Correto: {is_correct}')

    y_true.append(normalized_label)
    y_pred.append(clean_category(remove_accents(normalized_result.strip().upper())))

    total_count += 1
    if is_correct:
        correct_count += 1

    # Calcular métricas intermediárias
    intermediate_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    # Exibir métricas intermediárias
    print(f'Progresso: {index + 1}/{len(filtered_df)}')
    print(f'Acurácia até agora: {correct_count / total_count * 100:.2f}%')
    print(f'Precisão até agora: {intermediate_precision * 100:.2f}%')
    print(f'Recall até agora: {intermediate_recall * 100:.2f}%')
    print(f'F1-score até agora: {intermediate_f1 * 100:.2f}%')
    print()  # Adiciona uma linha em branco

    # Armazenar os resultados na lista
    results.append({
        'Real': row['issue_area'],
        'Previsto': normalized_result,
        'Correto': is_correct
    })

# Calcular métricas finais
final_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
final_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
final_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f'Acurácia final: {correct_count / total_count * 100:.2f}%')
print(f'Precisão final: {final_precision * 100:.2f}%')
print(f'Recall final: {final_recall * 100:.2f}%')
print(f'F1-score final: {final_f1 * 100:.2f}%')

# Ajustar a lista de rótulos
unique_labels = list(set(y_true + y_pred))
unique_labels.sort()  # Garantir que os rótulos estejam ordenados

# Gerar relatório de classificação
classification_report_str = classification_report(y_true, y_pred, labels=unique_labels)
print(classification_report_str)

# Salvar relatório de classificação em arquivos CSV e Excel
report_dict = classification_report(y_true, y_pred, labels=unique_labels, output_dict=True)
report_df = pd.DataFrame(report_dict).transpose()

report_csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classification_report_resumos.csv'
report_excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classification_report_resumos.xlsx'

report_df.to_csv(report_csv_path, index=True)
report_df.to_excel(report_excel_path, index=True)

print(f'Relatório de classificação salvo em {report_csv_path} e {report_excel_path}')

# Criar um DataFrame a partir dos resultados
results_df = pd.DataFrame(results)

# Salvar os resultados em arquivos CSV e Excel
csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classificacoes_resumos.csv'
excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classificacoes_resumos.xlsx'

results_df.to_csv(csv_path, index=False)
results_df.to_excel(excel_path, index=False)

print(f'Resultados salvos em {csv_path} e {excel_path}')
# Out:
# Real: INTIMACAO-NEGATIVA, Previsto: INTIMACAO-NEGATIVA, Correto: True
# Progresso: 1/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 3/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 4/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 5/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 6/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 7/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 8/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 9/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 10/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 11/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: DISSOLUCAO-DE-CONDOMINIO, Correto: True
# Progresso: 12/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 13/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 14/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 15/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 16/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 17/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 18/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 19/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 20/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 21/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 22/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 23/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 24/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 25/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 26/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: UNIFICACAO-DE-PENAS, Correto: True
# Progresso: 27/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 28/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 29/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 30/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 31/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 32/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 33/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 34/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 35/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 36/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 37/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 38/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 39/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 40/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 41/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 42/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 43/346
# Acurácia até agora: 100.00%
# Precisão até agora: 100.00%
# Recall até agora: 100.00%
# F1-score até agora: 100.00%
#
# Real: PROGRESSAO-DE-REGIME, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 44/346
# Acurácia até agora: 97.73%
# Precisão até agora: 96.59%
# Recall até agora: 97.73%
# F1-score até agora: 96.97%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 45/346
# Acurácia até agora: 97.78%
# Precisão até agora: 96.67%
# Recall até agora: 97.78%
# F1-score até agora: 97.04%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 46/346
# Acurácia até agora: 97.83%
# Precisão até agora: 96.74%
# Recall até agora: 97.83%
# F1-score até agora: 97.10%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 47/346
# Acurácia até agora: 97.87%
# Precisão até agora: 96.81%
# Recall até agora: 97.87%
# F1-score até agora: 97.16%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 48/346
# Acurácia até agora: 97.92%
# Precisão até agora: 96.53%
# Recall até agora: 97.92%
# F1-score até agora: 97.08%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 49/346
# Acurácia até agora: 97.96%
# Precisão até agora: 96.60%
# Recall até agora: 97.96%
# F1-score até agora: 97.14%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 50/346
# Acurácia até agora: 98.00%
# Precisão até agora: 96.67%
# Recall até agora: 98.00%
# F1-score até agora: 97.20%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 51/346
# Acurácia até agora: 98.04%
# Precisão até agora: 96.73%
# Recall até agora: 98.04%
# F1-score até agora: 97.25%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 52/346
# Acurácia até agora: 98.08%
# Precisão até agora: 96.79%
# Recall até agora: 98.08%
# F1-score até agora: 97.31%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 53/346
# Acurácia até agora: 98.11%
# Precisão até agora: 96.86%
# Recall até agora: 98.11%
# F1-score até agora: 97.36%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 54/346
# Acurácia até agora: 98.15%
# Precisão até agora: 96.91%
# Recall até agora: 98.15%
# F1-score até agora: 97.41%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 55/346
# Acurácia até agora: 98.18%
# Precisão até agora: 96.97%
# Recall até agora: 98.18%
# F1-score até agora: 97.45%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 56/346
# Acurácia até agora: 98.21%
# Precisão até agora: 97.02%
# Recall até agora: 98.21%
# F1-score até agora: 97.50%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 57/346
# Acurácia até agora: 98.25%
# Precisão até agora: 97.08%
# Recall até agora: 98.25%
# F1-score até agora: 97.54%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 58/346
# Acurácia até agora: 98.28%
# Precisão até agora: 97.13%
# Recall até agora: 98.28%
# F1-score até agora: 97.59%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 59/346
# Acurácia até agora: 98.31%
# Precisão até agora: 97.18%
# Recall até agora: 98.31%
# F1-score até agora: 97.63%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 60/346
# Acurácia até agora: 98.33%
# Precisão até agora: 97.22%
# Recall até agora: 98.33%
# F1-score até agora: 97.67%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 61/346
# Acurácia até agora: 98.36%
# Precisão até agora: 97.27%
# Recall até agora: 98.36%
# F1-score até agora: 97.70%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 62/346
# Acurácia até agora: 98.39%
# Precisão até agora: 97.31%
# Recall até agora: 98.39%
# F1-score até agora: 97.74%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 63/346
# Acurácia até agora: 98.41%
# Precisão até agora: 97.35%
# Recall até agora: 98.41%
# F1-score até agora: 97.78%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 64/346
# Acurácia até agora: 98.44%
# Precisão até agora: 97.40%
# Recall até agora: 98.44%
# F1-score até agora: 97.81%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 65/346
# Acurácia até agora: 98.46%
# Precisão até agora: 97.44%
# Recall até agora: 98.46%
# F1-score até agora: 97.85%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 66/346
# Acurácia até agora: 98.48%
# Precisão até agora: 97.47%
# Recall até agora: 98.48%
# F1-score até agora: 97.88%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 67/346
# Acurácia até agora: 98.51%
# Precisão até agora: 97.39%
# Recall até agora: 98.51%
# F1-score até agora: 97.87%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 68/346
# Acurácia até agora: 98.53%
# Precisão até agora: 97.43%
# Recall até agora: 98.53%
# F1-score até agora: 97.90%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 69/346
# Acurácia até agora: 98.55%
# Precisão até agora: 97.46%
# Recall até agora: 98.55%
# F1-score até agora: 97.93%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 70/346
# Acurácia até agora: 98.57%
# Precisão até agora: 97.50%
# Recall até agora: 98.57%
# F1-score até agora: 97.96%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 71/346
# Acurácia até agora: 98.59%
# Precisão até agora: 97.54%
# Recall até agora: 98.59%
# F1-score até agora: 97.99%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 72/346
# Acurácia até agora: 98.61%
# Precisão até agora: 97.57%
# Recall até agora: 98.61%
# F1-score até agora: 98.02%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 73/346
# Acurácia até agora: 98.63%
# Precisão até agora: 97.60%
# Recall até agora: 98.63%
# F1-score até agora: 98.04%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 74/346
# Acurácia até agora: 98.65%
# Precisão até agora: 97.64%
# Recall até agora: 98.65%
# F1-score até agora: 98.07%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 75/346
# Acurácia até agora: 98.67%
# Precisão até agora: 97.67%
# Recall até agora: 98.67%
# F1-score até agora: 98.10%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 76/346
# Acurácia até agora: 98.68%
# Precisão até agora: 97.70%
# Recall até agora: 98.68%
# F1-score até agora: 98.12%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 77/346
# Acurácia até agora: 98.70%
# Precisão até agora: 97.73%
# Recall até agora: 98.70%
# F1-score até agora: 98.14%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 78/346
# Acurácia até agora: 98.72%
# Precisão até agora: 97.76%
# Recall até agora: 98.72%
# F1-score até agora: 98.17%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 79/346
# Acurácia até agora: 98.73%
# Precisão até agora: 97.78%
# Recall até agora: 98.73%
# F1-score até agora: 98.19%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 80/346
# Acurácia até agora: 98.75%
# Precisão até agora: 97.81%
# Recall até agora: 98.75%
# F1-score até agora: 98.21%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 81/346
# Acurácia até agora: 98.77%
# Precisão até agora: 97.84%
# Recall até agora: 98.77%
# F1-score até agora: 98.24%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 82/346
# Acurácia até agora: 98.78%
# Precisão até agora: 97.87%
# Recall até agora: 98.78%
# F1-score até agora: 98.26%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 83/346
# Acurácia até agora: 98.80%
# Precisão até agora: 97.89%
# Recall até agora: 98.80%
# F1-score até agora: 98.28%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 84/346
# Acurácia até agora: 98.81%
# Precisão até agora: 97.92%
# Recall até agora: 98.81%
# F1-score até agora: 98.30%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 85/346
# Acurácia até agora: 98.82%
# Precisão até agora: 97.94%
# Recall até agora: 98.82%
# F1-score até agora: 98.32%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 86/346
# Acurácia até agora: 98.84%
# Precisão até agora: 97.97%
# Recall até agora: 98.84%
# F1-score até agora: 98.34%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 87/346
# Acurácia até agora: 98.85%
# Precisão até agora: 97.99%
# Recall até agora: 98.85%
# F1-score até agora: 98.36%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 88/346
# Acurácia até agora: 98.86%
# Precisão até agora: 98.01%
# Recall até agora: 98.86%
# F1-score até agora: 98.38%
#
# Real: SAIDA-TEMPORARIA, Previsto: SAIDA-TEMPORARIA, Correto: True
# Progresso: 89/346
# Acurácia até agora: 98.88%
# Precisão até agora: 98.03%
# Recall até agora: 98.88%
# F1-score até agora: 98.39%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 90/346
# Acurácia até agora: 98.89%
# Precisão até agora: 98.06%
# Recall até agora: 98.89%
# F1-score até agora: 98.41%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 91/346
# Acurácia até agora: 98.90%
# Precisão até agora: 98.08%
# Recall até agora: 98.90%
# F1-score até agora: 98.43%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 92/346
# Acurácia até agora: 98.91%
# Precisão até agora: 98.10%
# Recall até agora: 98.91%
# F1-score até agora: 98.45%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 93/346
# Acurácia até agora: 98.92%
# Precisão até agora: 98.12%
# Recall até agora: 98.92%
# F1-score até agora: 98.46%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 94/346
# Acurácia até agora: 98.94%
# Precisão até agora: 98.14%
# Recall até agora: 98.94%
# F1-score até agora: 98.48%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 95/346
# Acurácia até agora: 98.95%
# Precisão até agora: 98.16%
# Recall até agora: 98.95%
# F1-score até agora: 98.50%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 96/346
# Acurácia até agora: 98.96%
# Precisão até agora: 98.18%
# Recall até agora: 98.96%
# F1-score até agora: 98.51%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 97/346
# Acurácia até agora: 98.97%
# Precisão até agora: 98.20%
# Recall até agora: 98.97%
# F1-score até agora: 98.53%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 98/346
# Acurácia até agora: 98.98%
# Precisão até agora: 98.21%
# Recall até agora: 98.98%
# F1-score até agora: 98.54%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 99/346
# Acurácia até agora: 98.99%
# Precisão até agora: 98.23%
# Recall até agora: 98.99%
# F1-score até agora: 98.56%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 100/346
# Acurácia até agora: 99.00%
# Precisão até agora: 98.20%
# Recall até agora: 99.00%
# F1-score até agora: 98.56%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 101/346
# Acurácia até agora: 99.01%
# Precisão até agora: 98.22%
# Recall até agora: 99.01%
# F1-score até agora: 98.57%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 102/346
# Acurácia até agora: 99.02%
# Precisão até agora: 98.24%
# Recall até agora: 99.02%
# F1-score até agora: 98.58%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 103/346
# Acurácia até agora: 99.03%
# Precisão até agora: 98.25%
# Recall até agora: 99.03%
# F1-score até agora: 98.60%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 104/346
# Acurácia até agora: 99.04%
# Precisão até agora: 98.27%
# Recall até agora: 99.04%
# F1-score até agora: 98.61%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: True
# Progresso: 105/346
# Acurácia até agora: 99.05%
# Precisão até agora: 98.29%
# Recall até agora: 99.05%
# F1-score até agora: 98.62%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 106/346
# Acurácia até agora: 99.06%
# Precisão até agora: 98.30%
# Recall até agora: 99.06%
# F1-score até agora: 98.64%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 107/346
# Acurácia até agora: 99.07%
# Precisão até agora: 98.32%
# Recall até agora: 99.07%
# F1-score até agora: 98.65%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 108/346
# Acurácia até agora: 99.07%
# Precisão até agora: 98.33%
# Recall até agora: 99.07%
# F1-score até agora: 98.66%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 109/346
# Acurácia até agora: 99.08%
# Precisão até agora: 98.35%
# Recall até agora: 99.08%
# F1-score até agora: 98.67%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 110/346
# Acurácia até agora: 99.09%
# Precisão até agora: 98.36%
# Recall até agora: 99.09%
# F1-score até agora: 98.69%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 111/346
# Acurácia até agora: 99.10%
# Precisão até agora: 98.38%
# Recall até agora: 99.10%
# F1-score até agora: 98.70%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 112/346
# Acurácia até agora: 99.11%
# Precisão até agora: 98.39%
# Recall até agora: 99.11%
# F1-score até agora: 98.71%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 113/346
# Acurácia até agora: 99.12%
# Precisão até agora: 98.41%
# Recall até agora: 99.12%
# F1-score até agora: 98.72%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 114/346
# Acurácia até agora: 99.12%
# Precisão até agora: 98.42%
# Recall até agora: 99.12%
# F1-score até agora: 98.73%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 115/346
# Acurácia até agora: 99.13%
# Precisão até agora: 98.43%
# Recall até agora: 99.13%
# F1-score até agora: 98.74%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 116/346
# Acurácia até agora: 99.14%
# Precisão até agora: 98.45%
# Recall até agora: 99.14%
# F1-score até agora: 98.75%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 117/346
# Acurácia até agora: 99.15%
# Precisão até agora: 98.46%
# Recall até agora: 99.15%
# F1-score até agora: 98.77%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 118/346
# Acurácia até agora: 99.15%
# Precisão até agora: 98.47%
# Recall até agora: 99.15%
# F1-score até agora: 98.78%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 119/346
# Acurácia até agora: 99.16%
# Precisão até agora: 98.49%
# Recall até agora: 99.16%
# F1-score até agora: 98.79%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 120/346
# Acurácia até agora: 99.17%
# Precisão até agora: 98.50%
# Recall até agora: 99.17%
# F1-score até agora: 98.80%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 121/346
# Acurácia até agora: 99.17%
# Precisão até agora: 98.51%
# Recall até agora: 99.17%
# F1-score até agora: 98.81%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 122/346
# Acurácia até agora: 99.18%
# Precisão até agora: 98.52%
# Recall até agora: 99.18%
# F1-score até agora: 98.82%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 123/346
# Acurácia até agora: 99.19%
# Precisão até agora: 98.54%
# Recall até agora: 99.19%
# F1-score até agora: 98.83%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 124/346
# Acurácia até agora: 99.19%
# Precisão até agora: 98.55%
# Recall até agora: 99.19%
# F1-score até agora: 98.84%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 125/346
# Acurácia até agora: 99.20%
# Precisão até agora: 98.56%
# Recall até agora: 99.20%
# F1-score até agora: 98.84%
#
# Real: CONSIGNACAO-EM-PAGAMENTO, Previsto: CONSIGNACAO-EM-PAGAMENTO, Correto: True
# Progresso: 126/346
# Acurácia até agora: 99.21%
# Precisão até agora: 98.57%
# Recall até agora: 99.21%
# F1-score até agora: 98.85%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 127/346
# Acurácia até agora: 99.21%
# Precisão até agora: 98.58%
# Recall até agora: 99.21%
# F1-score até agora: 98.86%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 128/346
# Acurácia até agora: 99.22%
# Precisão até agora: 98.59%
# Recall até agora: 99.22%
# F1-score até agora: 98.87%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 129/346
# Acurácia até agora: 99.22%
# Precisão até agora: 98.60%
# Recall até agora: 99.22%
# F1-score até agora: 98.88%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 130/346
# Acurácia até agora: 99.23%
# Precisão até agora: 98.62%
# Recall até agora: 99.23%
# F1-score até agora: 98.89%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 131/346
# Acurácia até agora: 99.24%
# Precisão até agora: 98.63%
# Recall até agora: 99.24%
# F1-score até agora: 98.90%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 132/346
# Acurácia até agora: 99.24%
# Precisão até agora: 98.64%
# Recall até agora: 99.24%
# F1-score até agora: 98.91%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 133/346
# Acurácia até agora: 99.25%
# Precisão até agora: 98.65%
# Recall até agora: 99.25%
# F1-score até agora: 98.91%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 134/346
# Acurácia até agora: 99.25%
# Precisão até agora: 98.66%
# Recall até agora: 99.25%
# F1-score até agora: 98.92%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 135/346
# Acurácia até agora: 99.26%
# Precisão até agora: 98.64%
# Recall até agora: 99.26%
# F1-score até agora: 98.92%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 136/346
# Acurácia até agora: 99.26%
# Precisão até agora: 98.65%
# Recall até agora: 99.26%
# F1-score até agora: 98.93%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 137/346
# Acurácia até agora: 99.27%
# Precisão até agora: 98.66%
# Recall até agora: 99.27%
# F1-score até agora: 98.94%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 138/346
# Acurácia até agora: 99.28%
# Precisão até agora: 98.67%
# Recall até agora: 99.28%
# F1-score até agora: 98.95%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 139/346
# Acurácia até agora: 99.28%
# Precisão até agora: 98.68%
# Recall até agora: 99.28%
# F1-score até agora: 98.95%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 140/346
# Acurácia até agora: 99.29%
# Precisão até agora: 98.69%
# Recall até agora: 99.29%
# F1-score até agora: 98.96%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 141/346
# Acurácia até agora: 99.29%
# Precisão até agora: 98.70%
# Recall até agora: 99.29%
# F1-score até agora: 98.97%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 142/346
# Acurácia até agora: 99.30%
# Precisão até agora: 98.71%
# Recall até agora: 99.30%
# F1-score até agora: 98.98%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 143/346
# Acurácia até agora: 99.30%
# Precisão até agora: 98.72%
# Recall até agora: 99.30%
# F1-score até agora: 98.98%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 144/346
# Acurácia até agora: 99.31%
# Precisão até agora: 98.73%
# Recall até agora: 99.31%
# F1-score até agora: 98.99%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 145/346
# Acurácia até agora: 99.31%
# Precisão até agora: 98.74%
# Recall até agora: 99.31%
# F1-score até agora: 99.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 146/346
# Acurácia até agora: 99.32%
# Precisão até agora: 98.74%
# Recall até agora: 99.32%
# F1-score até agora: 99.00%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 147/346
# Acurácia até agora: 99.32%
# Precisão até agora: 98.75%
# Recall até agora: 99.32%
# F1-score até agora: 99.01%
#
# Real: INTIMACAO-NEGATIVA, Previsto: INTIMACAO-NEGATIVA, Correto: True
# Progresso: 148/346
# Acurácia até agora: 99.32%
# Precisão até agora: 98.76%
# Recall até agora: 99.32%
# F1-score até agora: 99.02%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 149/346
# Acurácia até agora: 99.33%
# Precisão até agora: 98.77%
# Recall até agora: 99.33%
# F1-score até agora: 99.02%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 150/346
# Acurácia até agora: 99.33%
# Precisão até agora: 98.78%
# Recall até agora: 99.33%
# F1-score até agora: 99.03%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 151/346
# Acurácia até agora: 99.34%
# Precisão até agora: 98.79%
# Recall até agora: 99.34%
# F1-score até agora: 99.04%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 152/346
# Acurácia até agora: 99.34%
# Precisão até agora: 98.79%
# Recall até agora: 99.34%
# F1-score até agora: 99.04%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 153/346
# Acurácia até agora: 99.35%
# Precisão até agora: 98.80%
# Recall até agora: 99.35%
# F1-score até agora: 99.05%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: DISSOLUCAO-DE-CONDOMINIO, Correto: True
# Progresso: 154/346
# Acurácia até agora: 99.35%
# Precisão até agora: 98.81%
# Recall até agora: 99.35%
# F1-score até agora: 99.06%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 155/346
# Acurácia até agora: 99.35%
# Precisão até agora: 98.82%
# Recall até agora: 99.35%
# F1-score até agora: 99.06%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 156/346
# Acurácia até agora: 99.36%
# Precisão até agora: 98.82%
# Recall até agora: 99.36%
# F1-score até agora: 99.07%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 157/346
# Acurácia até agora: 99.36%
# Precisão até agora: 98.83%
# Recall até agora: 99.36%
# F1-score até agora: 99.07%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 158/346
# Acurácia até agora: 99.37%
# Precisão até agora: 98.84%
# Recall até agora: 99.37%
# F1-score até agora: 99.08%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 159/346
# Acurácia até agora: 99.37%
# Precisão até agora: 98.85%
# Recall até agora: 99.37%
# F1-score até agora: 99.09%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 160/346
# Acurácia até agora: 99.38%
# Precisão até agora: 98.85%
# Recall até agora: 99.38%
# F1-score até agora: 99.09%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 161/346
# Acurácia até agora: 99.38%
# Precisão até agora: 98.86%
# Recall até agora: 99.38%
# F1-score até agora: 99.10%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 162/346
# Acurácia até agora: 99.38%
# Precisão até agora: 98.87%
# Recall até agora: 99.38%
# F1-score até agora: 99.10%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 163/346
# Acurácia até agora: 99.39%
# Precisão até agora: 98.88%
# Recall até agora: 99.39%
# F1-score até agora: 99.11%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 164/346
# Acurácia até agora: 99.39%
# Precisão até agora: 98.88%
# Recall até agora: 99.39%
# F1-score até agora: 99.11%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 165/346
# Acurácia até agora: 99.39%
# Precisão até agora: 98.89%
# Recall até agora: 99.39%
# F1-score até agora: 99.12%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 166/346
# Acurácia até agora: 99.40%
# Precisão até agora: 98.88%
# Recall até agora: 99.40%
# F1-score até agora: 99.12%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 167/346
# Acurácia até agora: 99.40%
# Precisão até agora: 98.89%
# Recall até agora: 99.40%
# F1-score até agora: 99.12%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 168/346
# Acurácia até agora: 99.40%
# Precisão até agora: 98.89%
# Recall até agora: 99.40%
# F1-score até agora: 99.13%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 169/346
# Acurácia até agora: 99.41%
# Precisão até agora: 98.89%
# Recall até agora: 99.41%
# F1-score até agora: 99.13%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 170/346
# Acurácia até agora: 99.41%
# Precisão até agora: 98.90%
# Recall até agora: 99.41%
# F1-score até agora: 99.14%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 171/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.90%
# Recall até agora: 99.42%
# F1-score até agora: 99.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 172/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.91%
# Recall até agora: 99.42%
# F1-score até agora: 99.15%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 173/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.92%
# Recall até agora: 99.42%
# F1-score até agora: 99.15%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: UNIFICACAO-DE-PENAS, Correto: True
# Progresso: 174/346
# Acurácia até agora: 99.43%
# Precisão até agora: 98.92%
# Recall até agora: 99.43%
# F1-score até agora: 99.16%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 175/346
# Acurácia até agora: 99.43%
# Precisão até agora: 98.93%
# Recall até agora: 99.43%
# F1-score até agora: 99.16%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 176/346
# Acurácia até agora: 99.43%
# Precisão até agora: 98.93%
# Recall até agora: 99.43%
# F1-score até agora: 99.17%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 177/346
# Acurácia até agora: 99.44%
# Precisão até agora: 98.94%
# Recall até agora: 99.44%
# F1-score até agora: 99.17%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 178/346
# Acurácia até agora: 99.44%
# Precisão até agora: 98.95%
# Recall até agora: 99.44%
# F1-score até agora: 99.18%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 179/346
# Acurácia até agora: 99.44%
# Precisão até agora: 98.95%
# Recall até agora: 99.44%
# F1-score até agora: 99.18%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 180/346
# Acurácia até agora: 99.44%
# Precisão até agora: 98.96%
# Recall até agora: 99.44%
# F1-score até agora: 99.19%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 181/346
# Acurácia até agora: 99.45%
# Precisão até agora: 98.96%
# Recall até agora: 99.45%
# F1-score até agora: 99.19%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 182/346
# Acurácia até agora: 99.45%
# Precisão até agora: 98.96%
# Recall até agora: 99.45%
# F1-score até agora: 99.19%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 183/346
# Acurácia até agora: 99.45%
# Precisão até agora: 98.97%
# Recall até agora: 99.45%
# F1-score até agora: 99.20%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 184/346
# Acurácia até agora: 99.46%
# Precisão até agora: 98.97%
# Recall até agora: 99.46%
# F1-score até agora: 99.20%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 185/346
# Acurácia até agora: 99.46%
# Precisão até agora: 98.98%
# Recall até agora: 99.46%
# F1-score até agora: 99.21%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 186/346
# Acurácia até agora: 99.46%
# Precisão até agora: 98.98%
# Recall até agora: 99.46%
# F1-score até agora: 99.21%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 187/346
# Acurácia até agora: 99.47%
# Precisão até agora: 98.99%
# Recall até agora: 99.47%
# F1-score até agora: 99.21%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 188/346
# Acurácia até agora: 99.47%
# Precisão até agora: 99.00%
# Recall até agora: 99.47%
# F1-score até agora: 99.22%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 189/346
# Acurácia até agora: 99.47%
# Precisão até agora: 99.00%
# Recall até agora: 99.47%
# F1-score até agora: 99.22%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 190/346
# Acurácia até agora: 99.47%
# Precisão até agora: 99.01%
# Recall até agora: 99.47%
# F1-score até agora: 99.23%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 191/346
# Acurácia até agora: 99.48%
# Precisão até agora: 99.01%
# Recall até agora: 99.48%
# F1-score até agora: 99.23%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 192/346
# Acurácia até agora: 99.48%
# Precisão até agora: 99.02%
# Recall até agora: 99.48%
# F1-score até agora: 99.23%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 193/346
# Acurácia até agora: 99.48%
# Precisão até agora: 99.02%
# Recall até agora: 99.48%
# F1-score até agora: 99.24%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 194/346
# Acurácia até agora: 99.48%
# Precisão até agora: 99.03%
# Recall até agora: 99.48%
# F1-score até agora: 99.24%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 195/346
# Acurácia até agora: 99.49%
# Precisão até agora: 99.03%
# Recall até agora: 99.49%
# F1-score até agora: 99.25%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 196/346
# Acurácia até agora: 99.49%
# Precisão até agora: 99.04%
# Recall até agora: 99.49%
# F1-score até agora: 99.25%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 197/346
# Acurácia até agora: 99.49%
# Precisão até agora: 99.04%
# Recall até agora: 99.49%
# F1-score até agora: 99.25%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 198/346
# Acurácia até agora: 99.49%
# Precisão até agora: 99.05%
# Recall até agora: 99.49%
# F1-score até agora: 99.26%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 199/346
# Acurácia até agora: 99.50%
# Precisão até agora: 99.05%
# Recall até agora: 99.50%
# F1-score até agora: 99.26%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 200/346
# Acurácia até agora: 99.50%
# Precisão até agora: 99.06%
# Recall até agora: 99.50%
# F1-score até agora: 99.26%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 201/346
# Acurácia até agora: 99.50%
# Precisão até agora: 99.06%
# Recall até agora: 99.50%
# F1-score até agora: 99.27%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 202/346
# Acurácia até agora: 99.50%
# Precisão até agora: 99.06%
# Recall até agora: 99.50%
# F1-score até agora: 99.27%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 203/346
# Acurácia até agora: 99.51%
# Precisão até agora: 99.07%
# Recall até agora: 99.51%
# F1-score até agora: 99.28%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 204/346
# Acurácia até agora: 99.51%
# Precisão até agora: 99.07%
# Recall até agora: 99.51%
# F1-score até agora: 99.28%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 205/346
# Acurácia até agora: 99.51%
# Precisão até agora: 99.08%
# Recall até agora: 99.51%
# F1-score até agora: 99.28%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 206/346
# Acurácia até agora: 99.51%
# Precisão até agora: 99.08%
# Recall até agora: 99.51%
# F1-score até agora: 99.29%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 207/346
# Acurácia até agora: 99.52%
# Precisão até agora: 99.09%
# Recall até agora: 99.52%
# F1-score até agora: 99.29%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 208/346
# Acurácia até agora: 99.52%
# Precisão até agora: 99.09%
# Recall até agora: 99.52%
# F1-score até agora: 99.29%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 209/346
# Acurácia até agora: 99.52%
# Precisão até agora: 99.10%
# Recall até agora: 99.52%
# F1-score até agora: 99.30%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 210/346
# Acurácia até agora: 99.52%
# Precisão até agora: 99.10%
# Recall até agora: 99.52%
# F1-score até agora: 99.30%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 211/346
# Acurácia até agora: 99.53%
# Precisão até agora: 99.10%
# Recall até agora: 99.53%
# F1-score até agora: 99.30%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 212/346
# Acurácia até agora: 99.53%
# Precisão até agora: 99.11%
# Recall até agora: 99.53%
# F1-score até agora: 99.31%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 213/346
# Acurácia até agora: 99.53%
# Precisão até agora: 99.11%
# Recall até agora: 99.53%
# F1-score até agora: 99.31%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 214/346
# Acurácia até agora: 99.53%
# Precisão até agora: 99.12%
# Recall até agora: 99.53%
# F1-score até agora: 99.31%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 215/346
# Acurácia até agora: 99.53%
# Precisão até agora: 99.12%
# Recall até agora: 99.53%
# F1-score até agora: 99.32%
#
# Real: USUCAPIAO, Previsto: USUCAPIAO, Correto: True
# Progresso: 216/346
# Acurácia até agora: 99.54%
# Precisão até agora: 99.13%
# Recall até agora: 99.54%
# F1-score até agora: 99.32%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 217/346
# Acurácia até agora: 99.54%
# Precisão até agora: 99.13%
# Recall até agora: 99.54%
# F1-score até agora: 99.32%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 218/346
# Acurácia até agora: 99.54%
# Precisão até agora: 99.13%
# Recall até agora: 99.54%
# F1-score até agora: 99.33%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 219/346
# Acurácia até agora: 99.54%
# Precisão até agora: 99.14%
# Recall até agora: 99.54%
# F1-score até agora: 99.33%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 220/346
# Acurácia até agora: 99.55%
# Precisão até agora: 99.14%
# Recall até agora: 99.55%
# F1-score até agora: 99.33%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 221/346
# Acurácia até agora: 99.55%
# Precisão até agora: 99.14%
# Recall até agora: 99.55%
# F1-score até agora: 99.33%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 222/346
# Acurácia até agora: 99.55%
# Precisão até agora: 99.14%
# Recall até agora: 99.55%
# F1-score até agora: 99.34%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 223/346
# Acurácia até agora: 99.55%
# Precisão até agora: 99.14%
# Recall até agora: 99.55%
# F1-score até agora: 99.34%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 224/346
# Acurácia até agora: 99.55%
# Precisão até agora: 99.15%
# Recall até agora: 99.55%
# F1-score até agora: 99.34%
#
# Real: CONTRARRAZOES-AO-AGRAVO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: True
# Progresso: 225/346
# Acurácia até agora: 99.56%
# Precisão até agora: 99.15%
# Recall até agora: 99.56%
# F1-score até agora: 99.34%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 226/346
# Acurácia até agora: 99.56%
# Precisão até agora: 99.16%
# Recall até agora: 99.56%
# F1-score até agora: 99.35%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 227/346
# Acurácia até agora: 99.56%
# Precisão até agora: 99.16%
# Recall até agora: 99.56%
# F1-score até agora: 99.35%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 228/346
# Acurácia até agora: 99.56%
# Precisão até agora: 99.16%
# Recall até agora: 99.56%
# F1-score até agora: 99.35%
#
# Real: INTIMACAO-NEGATIVA, Previsto: INTIMACAO-NEGATIVA, Correto: True
# Progresso: 229/346
# Acurácia até agora: 99.56%
# Precisão até agora: 99.17%
# Recall até agora: 99.56%
# F1-score até agora: 99.36%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 230/346
# Acurácia até agora: 99.57%
# Precisão até agora: 99.17%
# Recall até agora: 99.57%
# F1-score até agora: 99.36%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 231/346
# Acurácia até agora: 99.57%
# Precisão até agora: 99.17%
# Recall até agora: 99.57%
# F1-score até agora: 99.36%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 232/346
# Acurácia até agora: 99.57%
# Precisão até agora: 99.18%
# Recall até agora: 99.57%
# F1-score até agora: 99.36%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 233/346
# Acurácia até agora: 99.57%
# Precisão até agora: 99.18%
# Recall até agora: 99.57%
# F1-score até agora: 99.37%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 234/346
# Acurácia até agora: 99.57%
# Precisão até agora: 99.18%
# Recall até agora: 99.57%
# F1-score até agora: 99.37%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 235/346
# Acurácia até agora: 99.57%
# Precisão até agora: 99.19%
# Recall até agora: 99.57%
# F1-score até agora: 99.37%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 236/346
# Acurácia até agora: 99.58%
# Precisão até agora: 99.19%
# Recall até agora: 99.58%
# F1-score até agora: 99.37%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 237/346
# Acurácia até agora: 99.58%
# Precisão até agora: 99.19%
# Recall até agora: 99.58%
# F1-score até agora: 99.38%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 238/346
# Acurácia até agora: 99.58%
# Precisão até agora: 99.19%
# Recall até agora: 99.58%
# F1-score até agora: 99.38%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 239/346
# Acurácia até agora: 99.58%
# Precisão até agora: 99.20%
# Recall até agora: 99.58%
# F1-score até agora: 99.38%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 240/346
# Acurácia até agora: 99.58%
# Precisão até agora: 99.20%
# Recall até agora: 99.58%
# F1-score até agora: 99.38%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 241/346
# Acurácia até agora: 99.59%
# Precisão até agora: 99.20%
# Recall até agora: 99.59%
# F1-score até agora: 99.39%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 242/346
# Acurácia até agora: 99.59%
# Precisão até agora: 99.21%
# Recall até agora: 99.59%
# F1-score até agora: 99.39%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 243/346
# Acurácia até agora: 99.59%
# Precisão até agora: 99.21%
# Recall até agora: 99.59%
# F1-score até agora: 99.39%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 244/346
# Acurácia até agora: 99.59%
# Precisão até agora: 99.21%
# Recall até agora: 99.59%
# F1-score até agora: 99.39%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 245/346
# Acurácia até agora: 99.59%
# Precisão até agora: 99.22%
# Recall até agora: 99.59%
# F1-score até agora: 99.40%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 246/346
# Acurácia até agora: 99.59%
# Precisão até agora: 99.22%
# Recall até agora: 99.59%
# F1-score até agora: 99.40%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 247/346
# Acurácia até agora: 99.60%
# Precisão até agora: 99.22%
# Recall até agora: 99.60%
# F1-score até agora: 99.40%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 248/346
# Acurácia até agora: 99.60%
# Precisão até agora: 99.23%
# Recall até agora: 99.60%
# F1-score até agora: 99.40%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 249/346
# Acurácia até agora: 99.60%
# Precisão até agora: 99.23%
# Recall até agora: 99.60%
# F1-score até agora: 99.41%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 250/346
# Acurácia até agora: 99.60%
# Precisão até agora: 99.23%
# Recall até agora: 99.60%
# F1-score até agora: 99.41%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 251/346
# Acurácia até agora: 99.60%
# Precisão até agora: 99.24%
# Recall até agora: 99.60%
# F1-score até agora: 99.41%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 252/346
# Acurácia até agora: 99.60%
# Precisão até agora: 99.24%
# Recall até agora: 99.60%
# F1-score até agora: 99.41%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 253/346
# Acurácia até agora: 99.60%
# Precisão até agora: 99.24%
# Recall até agora: 99.60%
# F1-score até agora: 99.42%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: UNIFICACAO-DE-PENAS, Correto: True
# Progresso: 254/346
# Acurácia até agora: 99.61%
# Precisão até agora: 99.25%
# Recall até agora: 99.61%
# F1-score até agora: 99.42%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 255/346
# ...
# Acurácia até agora: 99.65%
# Precisão até agora: 99.33%
# Recall até agora: 99.65%
# F1-score até agora: 99.49%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 289/346
# Acurácia até agora: 99.65%
# Precisão até agora: 99.33%
# Recall até agora: 99.65%
# F1-score até agora: 99.49%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 290/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.33%
# Recall até agora: 99.66%
# F1-score até agora: 99.49%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 291/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.34%
# Recall até agora: 99.66%
# F1-score até agora: 99.49%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 292/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.34%
# Recall até agora: 99.66%
# F1-score até agora: 99.49%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 293/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.34%
# Recall até agora: 99.66%
# F1-score até agora: 99.49%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 294/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.34%
# Recall até agora: 99.66%
# F1-score até agora: 99.50%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 295/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.34%
# Recall até agora: 99.66%
# F1-score até agora: 99.50%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 296/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.35%
# Recall até agora: 99.66%
# F1-score até agora: 99.50%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 297/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.35%
# Recall até agora: 99.66%
# F1-score até agora: 99.50%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 298/346
# Acurácia até agora: 99.66%
# Precisão até agora: 99.35%
# Recall até agora: 99.66%
# F1-score até agora: 99.50%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 299/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.35%
# Recall até agora: 99.67%
# F1-score até agora: 99.50%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 300/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.35%
# Recall até agora: 99.67%
# F1-score até agora: 99.51%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 301/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.36%
# Recall até agora: 99.67%
# F1-score até agora: 99.51%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: DISSOLUCAO-DE-CONDOMINIO, Correto: True
# Progresso: 302/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.36%
# Recall até agora: 99.67%
# F1-score até agora: 99.51%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 303/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.36%
# Recall até agora: 99.67%
# F1-score até agora: 99.51%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 304/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.36%
# Recall até agora: 99.67%
# F1-score até agora: 99.51%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 305/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.36%
# Recall até agora: 99.67%
# F1-score até agora: 99.51%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 306/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.37%
# Recall até agora: 99.67%
# F1-score até agora: 99.52%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 307/346
# Acurácia até agora: 99.67%
# Precisão até agora: 99.37%
# Recall até agora: 99.67%
# F1-score até agora: 99.52%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 308/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.37%
# Recall até agora: 99.68%
# F1-score até agora: 99.52%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 309/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.37%
# Recall até agora: 99.68%
# F1-score até agora: 99.52%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 310/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.38%
# Recall até agora: 99.68%
# F1-score até agora: 99.52%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 311/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.38%
# Recall até agora: 99.68%
# F1-score até agora: 99.52%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 312/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.38%
# Recall até agora: 99.68%
# F1-score até agora: 99.52%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 313/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.38%
# Recall até agora: 99.68%
# F1-score até agora: 99.53%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 314/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.38%
# Recall até agora: 99.68%
# F1-score até agora: 99.53%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 315/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.38%
# Recall até agora: 99.68%
# F1-score até agora: 99.53%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 316/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.39%
# Recall até agora: 99.68%
# F1-score até agora: 99.53%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 317/346
# Acurácia até agora: 99.68%
# Precisão até agora: 99.39%
# Recall até agora: 99.68%
# F1-score até agora: 99.53%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 318/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.39%
# Recall até agora: 99.69%
# F1-score até agora: 99.53%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 319/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.39%
# Recall até agora: 99.69%
# F1-score até agora: 99.53%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 320/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.39%
# Recall até agora: 99.69%
# F1-score até agora: 99.54%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 321/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.40%
# Recall até agora: 99.69%
# F1-score até agora: 99.54%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 322/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.40%
# Recall até agora: 99.69%
# F1-score até agora: 99.54%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 323/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.40%
# Recall até agora: 99.69%
# F1-score até agora: 99.54%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 324/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.40%
# Recall até agora: 99.69%
# F1-score até agora: 99.54%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 325/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.40%
# Recall até agora: 99.69%
# F1-score até agora: 99.54%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 326/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.41%
# Recall até agora: 99.69%
# F1-score até agora: 99.54%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 327/346
# Acurácia até agora: 99.69%
# Precisão até agora: 99.41%
# Recall até agora: 99.69%
# F1-score até agora: 99.55%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 328/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.41%
# Recall até agora: 99.70%
# F1-score até agora: 99.55%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 329/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.41%
# Recall até agora: 99.70%
# F1-score até agora: 99.55%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 330/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.41%
# Recall até agora: 99.70%
# F1-score até agora: 99.55%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 331/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.41%
# Recall até agora: 99.70%
# F1-score até agora: 99.55%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 332/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.42%
# Recall até agora: 99.70%
# F1-score até agora: 99.55%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 333/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.42%
# Recall até agora: 99.70%
# F1-score até agora: 99.55%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 334/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.42%
# Recall até agora: 99.70%
# F1-score até agora: 99.56%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 335/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.42%
# Recall até agora: 99.70%
# F1-score até agora: 99.56%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 336/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.42%
# Recall até agora: 99.70%
# F1-score até agora: 99.56%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 337/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.43%
# Recall até agora: 99.70%
# F1-score até agora: 99.56%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 338/346
# Acurácia até agora: 99.70%
# Precisão até agora: 99.43%
# Recall até agora: 99.70%
# F1-score até agora: 99.56%
#
# Real: PROGRESSAO-DE-REGIME, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 339/346
# Acurácia até agora: 99.41%
# Precisão até agora: 98.89%
# Recall até agora: 99.41%
# F1-score até agora: 99.13%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 340/346
# Acurácia até agora: 99.41%
# Precisão até agora: 98.89%
# Recall até agora: 99.41%
# F1-score até agora: 99.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 341/346
# Acurácia até agora: 99.41%
# Precisão até agora: 98.90%
# Recall até agora: 99.41%
# F1-score até agora: 99.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 342/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.90%
# Recall até agora: 99.42%
# F1-score até agora: 99.14%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 343/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.90%
# Recall até agora: 99.42%
# F1-score até agora: 99.14%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 344/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.91%
# Recall até agora: 99.42%
# F1-score até agora: 99.15%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 345/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.91%
# Recall até agora: 99.42%
# F1-score até agora: 99.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 346/346
# Acurácia até agora: 99.42%
# Precisão até agora: 98.91%
# Recall até agora: 99.42%
# F1-score até agora: 99.15%
#
# Acurácia final: 99.42%
# Precisão final: 98.91%
# Recall final: 99.42%
# F1-score final: 99.15%
#                                     precision    recall  f1-score   support
#
#                             AGRAVO       1.00      1.00      1.00        44
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO       1.00      1.00      1.00         1
#                           APELACAO       1.00      1.00      1.00        30
#           CONSIGNACAO-EM-PAGAMENTO       1.00      1.00      1.00         1
#            CONTRARRAZOES-AO-AGRAVO       1.00      1.00      1.00         1
#             CUMPRIMENTO-DE-SETENCA       0.88      1.00      0.94        15
#           DISSOLUCAO-DE-CONDOMINIO       1.00      1.00      1.00         3
#                           EMBARGOS       1.00      1.00      1.00        31
#       EXCECAO-DE-PRE-EXECUTIVIDADE       1.00      1.00      1.00         9
#           EXTINCAO-DE-PUNIBILIDADE       1.00      1.00      1.00        50
#                      HABEAS-CORPUS       1.00      1.00      1.00         3
#                         IMPUGNACAO       1.00      1.00      1.00        42
#                     INDENIZATORIAS       1.00      1.00      1.00        15
#                  INDULTO-COMUTACAO       1.00      1.00      1.00        17
#                 INTIMACAO-NEGATIVA       1.00      1.00      1.00         3
#             LIVRAMENTO-CONDICIONAL       1.00      1.00      1.00        22
#                            OFICIOS       1.00      1.00      1.00        15
#               PROGRESSAO-DE-REGIME       0.00      0.00      0.00         2
#                     REGISTRO-CIVIL       1.00      1.00      1.00        23
#                    REMICAO-DE-PENA       1.00      1.00      1.00         3
#                   SAIDA-TEMPORARIA       1.00      1.00      1.00         1
#          TRANSFERENCIA-DE-EXECUCAO       1.00      1.00      1.00         8
#                UNIFICACAO-DE-PENAS       1.00      1.00      1.00         3
#                          USUCAPIAO       1.00      1.00      1.00         4
#
#                           accuracy                           0.99       346
#                          macro avg       0.95      0.96      0.96       346
#                       weighted avg       0.99      0.99      0.99       346
#
# Relatório de classificação salvo em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classification_report_resumos.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classification_report_resumos.xlsx
# Resultados salvos em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classificacoes_resumos.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Classificações/classificacoes_resumos.xlsx
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Converter categorias para números
label_mapping = {label: idx for idx, label in enumerate(set(y_true + y_pred))}
numeric_labels_true = [label_mapping[label] for label in y_true]
numeric_labels_pred = [label_mapping[label] for label in y_pred]

df_comparison = pd.DataFrame({'Real': numeric_labels_true, 'Previsto': numeric_labels_pred})

# Calcular a acurácia
accuracy = (df_comparison['Real'] == df_comparison['Previsto']).mean()

# Calcular a média móvel para suavizar as curvas
df_comparison['Real_Smooth'] = df_comparison['Real'].rolling(window=10).mean()
df_comparison['Previsto_Smooth'] = df_comparison['Previsto'].rolling(window=10).mean()

# Criar o gráfico de linhas
plt.figure(figsize=(10, 5))  # Tamanho ajustado do gráfico
plt.plot(df_comparison.index, df_comparison['Real_Smooth'], label='Real', linestyle='-', color='blue')
plt.plot(df_comparison.index, df_comparison['Previsto_Smooth'], label='Previsto', linestyle='--', color='orange', alpha=0.7)
plt.xlabel('Índice (Posição na Sequência)', fontsize=12)  # Eixo X representando a posição na sequência
plt.ylabel('Classificação Média (Média Móvel)', fontsize=12)  # Eixo Y representando a média móvel das classificações
plt.title('Classificação Real e Prevista', fontsize=15)
plt.legend(loc='upper right', fontsize=10, frameon=False)  # Reduzir o tamanho da fonte da legenda e remover o quadro
plt.show()

# Exibir a acurácia
print(f'Acurácia Total: {accuracy:.2%}')
# Out:
# Acurácia Total: 99.42%

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar os rótulos de string para valores numéricos
label_encoder = LabelEncoder()
y_true_encoded = label_encoder.fit_transform(y_true)
y_pred_encoded = label_encoder.transform(y_pred)

# Verificar o mapeamento
label_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'AGRAVO': 0, 'ALVARA-JUDICIAL-LIBERACAO-DE-CORPO': 1, 'APELACAO': 2, 'CONSIGNACAO-EM-PAGAMENTO': 3, 'CONTRARRAZOES-AO-AGRAVO': 4, 'CUMPRIMENTO-DE-SETENCA': 5, 'DISSOLUCAO-DE-CONDOMINIO': 6, 'EMBARGOS': 7, 'EXCECAO-DE-PRE-EXECUTIVIDADE': 8, 'EXTINCAO-DE-PUNIBILIDADE': 9, 'HABEAS-CORPUS': 10, 'IMPUGNACAO': 11, 'INDENIZATORIAS': 12, 'INDULTO-COMUTACAO': 13, 'INTIMACAO-NEGATIVA': 14, 'LIVRAMENTO-CONDICIONAL': 15, 'OFICIOS': 16, 'PROGRESSAO-DE-REGIME': 17, 'REGISTRO-CIVIL': 18, 'REMICAO-DE-PENA': 19, 'SAIDA-TEMPORARIA': 20, 'TRANSFERENCIA-DE-EXECUCAO': 21, 'UNIFICACAO-DE-PENAS': 22, 'USUCAPIAO': 23}

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

# Binarizar os rótulos para o cálculo do AUC-ROC
y_true_binarized = label_binarize(y_true, classes=unique_labels)
y_pred_binarized = label_binarize(y_pred, classes=unique_labels)

# Calcular o AUC-ROC para cada classe
roc_auc_scores = {}
for i, label in enumerate(unique_labels):
    roc_auc_scores[label] = roc_auc_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-ROC
average_auc_roc = sum(roc_auc_scores.values()) / len(roc_auc_scores)

# Imprimir as pontuações AUC-ROC
print("Pontuações AUC-ROC por classe:")
for label, score in roc_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-ROC: {average_auc_roc:.2f}")
# Out:
# Pontuações AUC-ROC por classe:
# AGRAVO: 1.00
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 1.00
# APELACAO: 1.00
# CONSIGNACAO-EM-PAGAMENTO: 1.00
# CONTRARRAZOES-AO-AGRAVO: 1.00
# CUMPRIMENTO-DE-SETENCA: 1.00
# DISSOLUCAO-DE-CONDOMINIO: 1.00
# EMBARGOS: 1.00
# EXCECAO-DE-PRE-EXECUTIVIDADE: 1.00
# EXTINCAO-DE-PUNIBILIDADE: 1.00
# HABEAS-CORPUS: 1.00
# IMPUGNACAO: 1.00
# INDENIZATORIAS: 1.00
# INDULTO-COMUTACAO: 1.00
# INTIMACAO-NEGATIVA: 1.00
# LIVRAMENTO-CONDICIONAL: 1.00
# OFICIOS: 1.00
# PROGRESSAO-DE-REGIME: 0.50
# REGISTRO-CIVIL: 1.00
# REMICAO-DE-PENA: 1.00
# SAIDA-TEMPORARIA: 1.00
# TRANSFERENCIA-DE-EXECUCAO: 1.00
# UNIFICACAO-DE-PENAS: 1.00
# USUCAPIAO: 1.00
# Média AUC-ROC: 0.98

# %%
from sklearn.metrics import average_precision_score

# Calcular o AUC-PR para cada classe
pr_auc_scores = {}
for i, label in enumerate(unique_labels):
    pr_auc_scores[label] = average_precision_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-PR
average_auc_pr = sum(pr_auc_scores.values()) / len(pr_auc_scores)

# Imprimir as pontuações AUC-PR
print("Pontuações AUC-PR por classe:")
for label, score in pr_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-PR: {average_auc_pr:.2f}")
# Out:
# Pontuações AUC-PR por classe:
# AGRAVO: 1.00
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 1.00
# APELACAO: 1.00
# CONSIGNACAO-EM-PAGAMENTO: 1.00
# CONTRARRAZOES-AO-AGRAVO: 1.00
# CUMPRIMENTO-DE-SETENCA: 0.88
# DISSOLUCAO-DE-CONDOMINIO: 1.00
# EMBARGOS: 1.00
# EXCECAO-DE-PRE-EXECUTIVIDADE: 1.00
# EXTINCAO-DE-PUNIBILIDADE: 1.00
# HABEAS-CORPUS: 1.00
# IMPUGNACAO: 1.00
# INDENIZATORIAS: 1.00
# INDULTO-COMUTACAO: 1.00
# INTIMACAO-NEGATIVA: 1.00
# LIVRAMENTO-CONDICIONAL: 1.00
# OFICIOS: 1.00
# PROGRESSAO-DE-REGIME: 0.01
# REGISTRO-CIVIL: 1.00
# REMICAO-DE-PENA: 1.00
# SAIDA-TEMPORARIA: 1.00
# TRANSFERENCIA-DE-EXECUCAO: 1.00
# UNIFICACAO-DE-PENAS: 1.00
# USUCAPIAO: 1.00
# Média AUC-PR: 0.95

# %%
from sklearn.metrics import matthews_corrcoef

# Calcular MCC
mcc_value = matthews_corrcoef(y_true, y_pred)

# Print MCC
print(f"MCC: {mcc_value:.2f}")
# Out:
# MCC: 0.99

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Calcular o relatório de classificação
report_dict = classification_report(y_true, y_pred, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()

# Remover categorias com resultados zero e médias indesejadas
df_report = df_report[(df_report['precision'] > 0) | (df_report['recall'] > 0) | (df_report['f1-score'] > 0)]
df_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg', 'micro avg'], errors='ignore')

# Ajustar a largura das barras
bar_width = 0.6

# Ordenar os valores para visualização pela precisão
df_report_precision = df_report.sort_values(by='precision', ascending=False)

# Precisão
plt.figure(figsize=(12, 5))
df_report_precision['precision'].plot(kind='bar', color='skyblue', width=bar_width)
plt.title('Precisão por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Precisão', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo recall
df_report_recall = df_report.sort_values(by='recall', ascending=False)

# Recall
plt.figure(figsize=(12, 5))
df_report_recall['recall'].plot(kind='bar', color='lightgreen', width=bar_width)
plt.title('Recall por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('Recall', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo f1-score
df_report_f1 = df_report.sort_values(by='f1-score', ascending=False)

# F1-Score
plt.figure(figsize=(12, 5))
df_report_f1['f1-score'].plot(kind='bar', color='salmon', width=bar_width)
plt.title('F1-Score por Categoria', fontsize=16)
plt.xlabel('Categoria', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

df_sample = pd.DataFrame({
    'issue_area': y_true,
    'resultados': y_pred
})

# Calcular a matriz de confusão
cm = confusion_matrix(df_sample['issue_area'], df_sample['resultados'], labels=df_sample['issue_area'].unique())

# Normalizar a matriz de confusão
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Criar rótulos numéricos para as categorias
categories = [f'Categoria {i+1}' for i in range(len(df_sample['issue_area'].unique()))]

# Criar DataFrames para as matrizes de confusão
df_cm = pd.DataFrame(cm, index=categories, columns=categories)
df_cm_normalized = pd.DataFrame(cm_normalized, index=categories, columns=categories)

# Definir o diretório de saída
output_dir = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/mistralai Mixtral-8x22B-Instruct-v0.1-V2/Classificação usando Resumos/Matriz-confusão'

# Salvar as matrizes de confusão em CSV e Excel
df_cm.to_csv(f'{output_dir}/matriz_de_confusao.csv', index=True)
df_cm_normalized.to_csv(f'{output_dir}/matriz_de_confusao_normalizada.csv', index=True)

df_cm.to_excel(f'{output_dir}/matriz_de_confusao.xlsx', index=True)
df_cm_normalized.to_excel(f'{output_dir}/matriz_de_confusao_normalizada.xlsx', index=True)

# Plotar a matriz de confusão normal
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Rótulo previsto', fontsize=14)
plt.ylabel('Rótulo verdadeiro', fontsize=14)
plt.title('Matriz de Confusão - Conjunto de Teste', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# Plotar a matriz de confusão normalizada
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Rótulo previsto', fontsize=14)
plt.ylabel('Rótulo verdadeiro', fontsize=14)
plt.title('Matriz de Confusão Normalizada - Conjunto de Teste', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()
